# %%
# Loading processed infinite chain data
import numpy as np
prob_swap_sweep_size = 100+1
prob_swap_range = np.arange(0, prob_swap_sweep_size)/(prob_swap_sweep_size-1) 
prob_succ_swap_range = [0.5, 0.75, 1]

results_inf = np.load('FOLDER_LOCATION/Infinite networks/Infinite chain/sweep_prob_swap_max_link_dist/M = 2, 3, 4 (comparison with finite chain)/results_M2M3M4.npy')

max_link_dist_range = [2, 3, 4]

virtual_node_degree_mean_inf = [results_inf[i*len(prob_swap_range)+j][0] for i in range(len(prob_succ_swap_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_mean_inf = [results_inf[i*len(prob_swap_range)+j][2] for i in range(len(prob_succ_swap_range)) for j in range(len(prob_swap_range))]

virtual_node_degree_mean_inf = np.reshape(virtual_node_degree_mean_inf, (len(prob_succ_swap_range), len(prob_swap_range)))
virtual_neighbourhood_size_mean_inf = np.reshape(virtual_neighbourhood_size_mean_inf, (len(prob_succ_swap_range), len(prob_swap_range)))

# %% [markdown]
# ### M = 4, L = 11

# %%
# Loading raw data
results = np.load('FOLDER_LOCATION/Finite networks/Finite chain/sweep_prob_swap_prob_succ_swap/Long runs/results.npy', allow_pickle=True)

virtual_node_degree = [results[i][18] for i in range(len(prob_swap_range))]
virtual_node_neighbourhood_size = [results[i][19] for i in range(len(prob_swap_range))]

virtual_node_degree = np.reshape(virtual_node_degree, (1, len(prob_swap_range), 11, 1, 500000))
virtual_node_neighbourhood_size = np.reshape(virtual_node_neighbourhood_size, (1, len(prob_swap_range), 11, 1, 500000))

# %%
# Prep raw data for post-processing
virtual_node_degree_center =  virtual_node_degree[0, :, 5, :, :]
virtual_node_degree_offcenter_1 =  np.dstack((virtual_node_degree[0, :, 4, :, :], virtual_node_degree[0, :, 6, :, :]))
virtual_node_degree_offcenter_2 =  np.dstack((virtual_node_degree[0, :, 3, :, :], virtual_node_degree[0, :, 7, :, :]))
virtual_node_degree_offcenter_3 =  np.dstack((virtual_node_degree[0, :, 2, :, :], virtual_node_degree[0, :, 8, :, :]))
virtual_node_degree_offcenter_4 =  np.dstack((virtual_node_degree[0, :, 1, :, :], virtual_node_degree[0, :, 9, :, :]))
virtual_node_degree_offcenter_5 =  np.dstack((virtual_node_degree[0, :, 0, :, :], virtual_node_degree[0, :, 10, :, :]))

virtual_node_neighbourhood_size_center =  virtual_node_neighbourhood_size[0, :, 5, :, :]
virtual_node_neighbourhood_size_offcenter_1 =  np.dstack((virtual_node_neighbourhood_size[0, :, 4, :, :],virtual_node_neighbourhood_size[0, :, 6, :, :]))
virtual_node_neighbourhood_size_offcenter_2 =  np.dstack((virtual_node_neighbourhood_size[0, :, 3, :, :], virtual_node_neighbourhood_size[0, :, 7, :, :]))
virtual_node_neighbourhood_size_offcenter_3 =  np.dstack((virtual_node_neighbourhood_size[0, :, 2, :, :], virtual_node_neighbourhood_size[0, :, 8, :, :]))
virtual_node_neighbourhood_size_offcenter_4 =  np.dstack((virtual_node_neighbourhood_size[0, :, 1, :, :], virtual_node_neighbourhood_size[0, :, 9, :, :]))
virtual_node_neighbourhood_size_offcenter_5 =  np.dstack((virtual_node_neighbourhood_size[0, :, 0, :, :], virtual_node_neighbourhood_size[0, :, 10, :, :]))

# %%
# Post-processing
virtual_node_degree_center_mean = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_mean = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_mean = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_mean = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_mean = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_mean = np.empty(prob_swap_sweep_size)


virtual_node_neighbourhood_size_center_mean = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_1_mean = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_2_mean = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_3_mean = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_4_mean = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_5_mean = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_10pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_10pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_10pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_10pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_10pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_10pct = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_25pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_25pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_25pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_25pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_25pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_25pct = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_75pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_75pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_75pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_75pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_75pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_75pct = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_90pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_90pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_90pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_90pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_90pct = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_90pct = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_10pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_10pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_10pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_10pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_10pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_10pct = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_25pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_25pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_25pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_25pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_25pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_25pct = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_75pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_75pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_75pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_75pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_75pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_75pct = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_90pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_90pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_90pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_90pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_90pct = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_90pct = np.empty(prob_swap_sweep_size)

for q in range(prob_swap_sweep_size):
    virtual_node_degree_center_mean[q] = np.mean(virtual_node_degree_center[q])
    virtual_node_degree_offcenter_1_mean[q] = np.mean(virtual_node_degree_offcenter_1[q])
    virtual_node_degree_offcenter_2_mean[q] = np.mean(virtual_node_degree_offcenter_2[q])
    virtual_node_degree_offcenter_3_mean[q] = np.mean(virtual_node_degree_offcenter_3[q])
    virtual_node_degree_offcenter_4_mean[q] = np.mean(virtual_node_degree_offcenter_4[q])
    virtual_node_degree_offcenter_5_mean[q] = np.mean(virtual_node_degree_offcenter_5[q])
    
    virtual_node_neighbourhood_size_center_mean[q] = np.mean(virtual_node_neighbourhood_size_center[q])
    virtual_node_neighbourhood_size_offcenter_1_mean[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_1[q])
    virtual_node_neighbourhood_size_offcenter_2_mean[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_2[q])
    virtual_node_neighbourhood_size_offcenter_3_mean[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_3[q])
    virtual_node_neighbourhood_size_offcenter_4_mean[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_4[q])
    virtual_node_neighbourhood_size_offcenter_5_mean[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_5[q])
    
    virtual_node_degree_center_10pct[q] = np.percentile(virtual_node_degree_center[q], 10)
    virtual_node_degree_offcenter_1_10pct[q] = np.percentile(virtual_node_degree_offcenter_1[q], 10)
    virtual_node_degree_offcenter_2_10pct[q] = np.percentile(virtual_node_degree_offcenter_2[q], 10)
    virtual_node_degree_offcenter_3_10pct[q] = np.percentile(virtual_node_degree_offcenter_3[q], 10)
    virtual_node_degree_offcenter_4_10pct[q] = np.percentile(virtual_node_degree_offcenter_4[q], 10)
    virtual_node_degree_offcenter_5_10pct[q] = np.percentile(virtual_node_degree_offcenter_5[q], 10)

    virtual_node_degree_center_25pct[q] = np.percentile(virtual_node_degree_center[q], 25)
    virtual_node_degree_offcenter_1_25pct[q] = np.percentile(virtual_node_degree_offcenter_1[q], 25)
    virtual_node_degree_offcenter_2_25pct[q] = np.percentile(virtual_node_degree_offcenter_2[q], 25)
    virtual_node_degree_offcenter_3_25pct[q] = np.percentile(virtual_node_degree_offcenter_3[q], 25)
    virtual_node_degree_offcenter_4_25pct[q] = np.percentile(virtual_node_degree_offcenter_4[q], 25)
    virtual_node_degree_offcenter_5_25pct[q] = np.percentile(virtual_node_degree_offcenter_5[q], 25)

    virtual_node_degree_center_75pct[q] = np.percentile(virtual_node_degree_center[q], 75)
    virtual_node_degree_offcenter_1_75pct[q] = np.percentile(virtual_node_degree_offcenter_1[q], 75)
    virtual_node_degree_offcenter_2_75pct[q] = np.percentile(virtual_node_degree_offcenter_2[q], 75)
    virtual_node_degree_offcenter_3_75pct[q] = np.percentile(virtual_node_degree_offcenter_3[q], 75)
    virtual_node_degree_offcenter_4_75pct[q] = np.percentile(virtual_node_degree_offcenter_4[q], 75)
    virtual_node_degree_offcenter_5_75pct[q] = np.percentile(virtual_node_degree_offcenter_5[q], 75)
    
    virtual_node_degree_center_90pct[q] = np.percentile(virtual_node_degree_center[q], 90)
    virtual_node_degree_offcenter_1_90pct[q] = np.percentile(virtual_node_degree_offcenter_1[q], 90)
    virtual_node_degree_offcenter_2_90pct[q] = np.percentile(virtual_node_degree_offcenter_2[q], 90)
    virtual_node_degree_offcenter_3_90pct[q] = np.percentile(virtual_node_degree_offcenter_3[q], 90)
    virtual_node_degree_offcenter_4_90pct[q] = np.percentile(virtual_node_degree_offcenter_4[q], 90)
    virtual_node_degree_offcenter_5_90pct[q] = np.percentile(virtual_node_degree_offcenter_5[q], 90)
    
    virtual_neighbourhood_size_center_10pct[q] = np.percentile(virtual_node_neighbourhood_size_center[q], 10)
    virtual_neighbourhood_size_offcenter_1_10pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1[q], 10)
    virtual_neighbourhood_size_offcenter_2_10pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2[q], 10)
    virtual_neighbourhood_size_offcenter_3_10pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3[q], 10)
    virtual_neighbourhood_size_offcenter_4_10pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4[q], 10)
    virtual_neighbourhood_size_offcenter_5_10pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5[q], 10)
    
    virtual_neighbourhood_size_center_25pct[q] = np.percentile(virtual_node_neighbourhood_size_center[q], 25)
    virtual_neighbourhood_size_offcenter_1_25pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1[q], 25)
    virtual_neighbourhood_size_offcenter_2_25pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2[q], 25)
    virtual_neighbourhood_size_offcenter_3_25pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3[q], 25)
    virtual_neighbourhood_size_offcenter_4_25pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4[q], 25)
    virtual_neighbourhood_size_offcenter_5_25pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5[q], 25)  
    
    virtual_neighbourhood_size_center_75pct[q] = np.percentile(virtual_node_neighbourhood_size_center[q], 75)
    virtual_neighbourhood_size_offcenter_1_75pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1[q], 75)
    virtual_neighbourhood_size_offcenter_2_75pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2[q], 75)
    virtual_neighbourhood_size_offcenter_3_75pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3[q], 75)
    virtual_neighbourhood_size_offcenter_4_75pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4[q], 75)
    virtual_neighbourhood_size_offcenter_5_75pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5[q], 75) 
    
    virtual_neighbourhood_size_center_90pct[q] = np.percentile(virtual_node_neighbourhood_size_center[q], 90, interpolation='nearest')
    virtual_neighbourhood_size_offcenter_1_90pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1[q], 90, interpolation='nearest')
    virtual_neighbourhood_size_offcenter_2_90pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2[q], 90, interpolation='nearest')
    virtual_neighbourhood_size_offcenter_3_90pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3[q], 90, interpolation='nearest')
    virtual_neighbourhood_size_offcenter_4_90pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4[q], 90, interpolation='nearest')
    virtual_neighbourhood_size_offcenter_5_90pct[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5[q], 90, interpolation='nearest')

# %% [markdown]
# ### M = 3, L = 11

# %%
prob_swap_sweep_size = 100+1
prob_swap_range = np.arange(0, prob_swap_sweep_size)/(prob_swap_sweep_size-1)
prob_succ_swap_range = [0.5, 0.75, 1]

results = np.load('FOLDER_LOCATION/Finite networks/Finite chain/sweep_prob_swap_prob_succ_swap/Long runs/results_M3_L11.npy', allow_pickle=True)

virtual_node_degree = [results[i][18] for i in range(len(prob_swap_range))]
virtual_node_neighbourhood_size = [results[i][19] for i in range(len(prob_swap_range))]

virtual_node_degree = np.reshape(virtual_node_degree, (1, len(prob_swap_range), 11, 1, 500000))
virtual_node_neighbourhood_size = np.reshape(virtual_node_neighbourhood_size, (1, len(prob_swap_range), 11, 1, 500000))

# %%
virtual_node_degree_center_M3 =  virtual_node_degree[0, :, 5, :, :]
virtual_node_degree_offcenter_1_M3 = np.dstack((virtual_node_degree[0, :, 4, :, :], virtual_node_degree[0, :, 6, :, :]))
virtual_node_degree_offcenter_2_M3 = np.dstack((virtual_node_degree[0, :, 3, :, :], virtual_node_degree[0, :, 7, :, :]))
virtual_node_degree_offcenter_3_M3 = np.dstack((virtual_node_degree[0, :, 2, :, :], virtual_node_degree[0, :, 8, :, :]))
virtual_node_degree_offcenter_4_M3 = np.dstack((virtual_node_degree[0, :, 1, :, :], virtual_node_degree[0, :, 9, :, :]))
virtual_node_degree_offcenter_5_M3 = np.dstack((virtual_node_degree[0, :, 0, :, :], virtual_node_degree[0, :, 10, :, :]))


virtual_node_neighbourhood_size_center_M3 = virtual_node_neighbourhood_size[0, :, 5, :, :]
virtual_node_neighbourhood_size_offcenter_1_M3 = np.dstack((virtual_node_neighbourhood_size[0, :, 4, :, :],virtual_node_neighbourhood_size[0, :, 6, :, :]))
virtual_node_neighbourhood_size_offcenter_2_M3 = np.dstack((virtual_node_neighbourhood_size[0, :, 3, :, :], virtual_node_neighbourhood_size[0, :, 7, :, :]))
virtual_node_neighbourhood_size_offcenter_3_M3 = np.dstack((virtual_node_neighbourhood_size[0, :, 2, :, :], virtual_node_neighbourhood_size[0, :, 8, :, :]))
virtual_node_neighbourhood_size_offcenter_4_M3 = np.dstack((virtual_node_neighbourhood_size[0, :, 1, :, :], virtual_node_neighbourhood_size[0, :, 9, :, :]))
virtual_node_neighbourhood_size_offcenter_5_M3 = np.dstack((virtual_node_neighbourhood_size[0, :, 0, :, :], virtual_node_neighbourhood_size[0, :, 10, :, :]))

# %%
virtual_node_degree_center_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_mean_M3 = np.empty(prob_swap_sweep_size)


virtual_node_neighbourhood_size_center_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_1_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_2_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_3_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_4_mean_M3 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_5_mean_M3 = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_10pct_M3 = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_25pct_M3 = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_75pct_M3 = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_90pct_M3 = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_10pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_10pct_M3 = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_25pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_25pct_M3 = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_75pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_75pct_M3 = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_90pct_M3 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_90pct_M3 = np.empty(prob_swap_sweep_size)

for q in range(prob_swap_sweep_size):
    virtual_node_degree_center_mean_M3[q] = np.mean(virtual_node_degree_center_M3[q])
    virtual_node_degree_offcenter_1_mean_M3[q] = np.mean(virtual_node_degree_offcenter_1_M3[q])
    virtual_node_degree_offcenter_2_mean_M3[q] = np.mean(virtual_node_degree_offcenter_2_M3[q])
    virtual_node_degree_offcenter_3_mean_M3[q] = np.mean(virtual_node_degree_offcenter_3_M3[q])
    virtual_node_degree_offcenter_4_mean_M3[q] = np.mean(virtual_node_degree_offcenter_4_M3[q])
    virtual_node_degree_offcenter_5_mean_M3[q] = np.mean(virtual_node_degree_offcenter_5_M3[q])
    
    virtual_node_neighbourhood_size_center_mean_M3[q] = np.mean(virtual_node_neighbourhood_size_center_M3[q])
    virtual_node_neighbourhood_size_offcenter_1_mean_M3[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_1_M3[q])
    virtual_node_neighbourhood_size_offcenter_2_mean_M3[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_2_M3[q])
    virtual_node_neighbourhood_size_offcenter_3_mean_M3[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_3_M3[q])
    virtual_node_neighbourhood_size_offcenter_4_mean_M3[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_4_M3[q])
    virtual_node_neighbourhood_size_offcenter_5_mean_M3[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_5_M3[q])
    
    virtual_node_degree_center_10pct_M3[q] = np.percentile(virtual_node_degree_center_M3[q], 10)
    virtual_node_degree_offcenter_1_10pct_M3[q] = np.percentile(virtual_node_degree_offcenter_1_M3[q], 10)
    virtual_node_degree_offcenter_2_10pct_M3[q] = np.percentile(virtual_node_degree_offcenter_2_M3[q], 10)
    virtual_node_degree_offcenter_3_10pct_M3[q] = np.percentile(virtual_node_degree_offcenter_3_M3[q], 10)
    virtual_node_degree_offcenter_4_10pct_M3[q] = np.percentile(virtual_node_degree_offcenter_4_M3[q], 10)
    virtual_node_degree_offcenter_5_10pct_M3[q] = np.percentile(virtual_node_degree_offcenter_5_M3[q], 10)

    virtual_node_degree_center_25pct_M3[q] = np.percentile(virtual_node_degree_center_M3[q], 25)
    virtual_node_degree_offcenter_1_25pct_M3[q] = np.percentile(virtual_node_degree_offcenter_1_M3[q], 25)
    virtual_node_degree_offcenter_2_25pct_M3[q] = np.percentile(virtual_node_degree_offcenter_2_M3[q], 25)
    virtual_node_degree_offcenter_3_25pct_M3[q] = np.percentile(virtual_node_degree_offcenter_3_M3[q], 25)
    virtual_node_degree_offcenter_4_25pct_M3[q] = np.percentile(virtual_node_degree_offcenter_4_M3[q], 25)
    virtual_node_degree_offcenter_5_25pct_M3[q] = np.percentile(virtual_node_degree_offcenter_5_M3[q], 25)

    virtual_node_degree_center_75pct_M3[q] = np.percentile(virtual_node_degree_center_M3[q], 75)
    virtual_node_degree_offcenter_1_75pct_M3[q] = np.percentile(virtual_node_degree_offcenter_1_M3[q], 75)
    virtual_node_degree_offcenter_2_75pct_M3[q] = np.percentile(virtual_node_degree_offcenter_2_M3[q], 75)
    virtual_node_degree_offcenter_3_75pct_M3[q] = np.percentile(virtual_node_degree_offcenter_3_M3[q], 75)
    virtual_node_degree_offcenter_4_75pct_M3[q] = np.percentile(virtual_node_degree_offcenter_4_M3[q], 75)
    virtual_node_degree_offcenter_5_75pct_M3[q] = np.percentile(virtual_node_degree_offcenter_5_M3[q], 75)
    
    virtual_node_degree_center_90pct_M3[q] = np.percentile(virtual_node_degree_center_M3[q], 90)
    virtual_node_degree_offcenter_1_90pct_M3[q] = np.percentile(virtual_node_degree_offcenter_1_M3[q], 90)
    virtual_node_degree_offcenter_2_90pct_M3[q] = np.percentile(virtual_node_degree_offcenter_2_M3[q], 90)
    virtual_node_degree_offcenter_3_90pct_M3[q] = np.percentile(virtual_node_degree_offcenter_3_M3[q], 90)
    virtual_node_degree_offcenter_4_90pct_M3[q] = np.percentile(virtual_node_degree_offcenter_4_M3[q], 90)
    virtual_node_degree_offcenter_5_90pct_M3[q] = np.percentile(virtual_node_degree_offcenter_5_M3[q], 90)
    
    virtual_neighbourhood_size_center_10pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_center_M3[q], 10)
    virtual_neighbourhood_size_offcenter_1_10pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1_M3[q], 10)
    virtual_neighbourhood_size_offcenter_2_10pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2_M3[q], 10)
    virtual_neighbourhood_size_offcenter_3_10pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3_M3[q], 10)
    virtual_neighbourhood_size_offcenter_4_10pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4_M3[q], 10)
    virtual_neighbourhood_size_offcenter_5_10pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5_M3[q], 10)
    
    virtual_neighbourhood_size_center_25pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_center_M3[q], 25)
    virtual_neighbourhood_size_offcenter_1_25pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1_M3[q], 25)
    virtual_neighbourhood_size_offcenter_2_25pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2_M3[q], 25)
    virtual_neighbourhood_size_offcenter_3_25pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3_M3[q], 25)
    virtual_neighbourhood_size_offcenter_4_25pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4_M3[q], 25)
    virtual_neighbourhood_size_offcenter_5_25pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5_M3[q], 25)  
    
    virtual_neighbourhood_size_center_75pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_center_M3[q], 75)
    virtual_neighbourhood_size_offcenter_1_75pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1_M3[q], 75)
    virtual_neighbourhood_size_offcenter_2_75pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2_M3[q], 75)
    virtual_neighbourhood_size_offcenter_3_75pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3_M3[q], 75)
    virtual_neighbourhood_size_offcenter_4_75pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4_M3[q], 75)
    virtual_neighbourhood_size_offcenter_5_75pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5_M3[q], 75) 
    
    virtual_neighbourhood_size_center_90pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_center_M3[q], 90)
    virtual_neighbourhood_size_offcenter_1_90pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1_M3[q], 90)
    virtual_neighbourhood_size_offcenter_2_90pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2_M3[q], 90)
    virtual_neighbourhood_size_offcenter_3_90pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3_M3[q], 90)
    virtual_neighbourhood_size_offcenter_4_90pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4_M3[q], 90)
    virtual_neighbourhood_size_offcenter_5_90pct_M3[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5_M3[q], 90)

# %% [markdown]
# ### M = 2 L = 11

# %%
prob_swap_sweep_size = 100+1
prob_swap_range = np.arange(0, prob_swap_sweep_size)/(prob_swap_sweep_size-1)
prob_succ_swap_range = [0.5, 0.75, 1]

results = np.load('FOLDER_LOCATION/Finite networks/Finite chain/sweep_prob_swap_prob_succ_swap/Long runs/results_M2_L11.npy', allow_pickle=True)

virtual_node_degree = [results[i][18] for i in range(len(prob_swap_range))]
virtual_node_neighbourhood_size = [results[i][19] for i in range(len(prob_swap_range))]

virtual_node_degree = np.reshape(virtual_node_degree, (1, len(prob_swap_range), 11, 1, 500000))
virtual_node_neighbourhood_size = np.reshape(virtual_node_neighbourhood_size, (1, len(prob_swap_range), 11, 1, 500000))

# %%
virtual_node_degree_center_M2 =  virtual_node_degree[0, :, 5, :, :]
virtual_node_degree_offcenter_1_M2 = np.dstack((virtual_node_degree[0, :, 4, :, :], virtual_node_degree[0, :, 6, :, :]))
virtual_node_degree_offcenter_2_M2 = np.dstack((virtual_node_degree[0, :, 3, :, :], virtual_node_degree[0, :, 7, :, :]))
virtual_node_degree_offcenter_3_M2 = np.dstack((virtual_node_degree[0, :, 2, :, :], virtual_node_degree[0, :, 8, :, :]))
virtual_node_degree_offcenter_4_M2 = np.dstack((virtual_node_degree[0, :, 1, :, :], virtual_node_degree[0, :, 9, :, :]))
virtual_node_degree_offcenter_5_M2 = np.dstack((virtual_node_degree[0, :, 0, :, :], virtual_node_degree[0, :, 10, :, :]))


virtual_node_neighbourhood_size_center_M2 =  virtual_node_neighbourhood_size[0, :, 5, :, :]
virtual_node_neighbourhood_size_offcenter_1_M2 = np.dstack((virtual_node_neighbourhood_size[0, :, 4, :, :],virtual_node_neighbourhood_size[0, :, 6, :, :]))
virtual_node_neighbourhood_size_offcenter_2_M2 = np.dstack((virtual_node_neighbourhood_size[0, :, 3, :, :], virtual_node_neighbourhood_size[0, :, 7, :, :]))
virtual_node_neighbourhood_size_offcenter_3_M2 = np.dstack((virtual_node_neighbourhood_size[0, :, 2, :, :], virtual_node_neighbourhood_size[0, :, 8, :, :]))
virtual_node_neighbourhood_size_offcenter_4_M2 = np.dstack((virtual_node_neighbourhood_size[0, :, 1, :, :], virtual_node_neighbourhood_size[0, :, 9, :, :]))
virtual_node_neighbourhood_size_offcenter_5_M2 = np.dstack((virtual_node_neighbourhood_size[0, :, 0, :, :], virtual_node_neighbourhood_size[0, :, 10, :, :]))

# %%
virtual_node_degree_center_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_mean_M2 = np.empty(prob_swap_sweep_size)


virtual_node_neighbourhood_size_center_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_1_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_2_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_3_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_4_mean_M2 = np.empty(prob_swap_sweep_size)
virtual_node_neighbourhood_size_offcenter_5_mean_M2 = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_10pct_M2 = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_25pct_M2 = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_75pct_M2 = np.empty(prob_swap_sweep_size)

virtual_node_degree_center_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_1_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_2_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_3_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_4_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_node_degree_offcenter_5_90pct_M2 = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_10pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_10pct_M2 = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_25pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_25pct_M2 = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_75pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_75pct_M2 = np.empty(prob_swap_sweep_size)

virtual_neighbourhood_size_center_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_1_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_2_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_3_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_4_90pct_M2 = np.empty(prob_swap_sweep_size)
virtual_neighbourhood_size_offcenter_5_90pct_M2 = np.empty(prob_swap_sweep_size)

for q in range(prob_swap_sweep_size):
    virtual_node_degree_center_mean_M2[q] = np.mean(virtual_node_degree_center_M2[q])
    virtual_node_degree_offcenter_1_mean_M2[q] = np.mean(virtual_node_degree_offcenter_1_M2[q])
    virtual_node_degree_offcenter_2_mean_M2[q] = np.mean(virtual_node_degree_offcenter_2_M2[q])
    virtual_node_degree_offcenter_3_mean_M2[q] = np.mean(virtual_node_degree_offcenter_3_M2[q])
    virtual_node_degree_offcenter_4_mean_M2[q] = np.mean(virtual_node_degree_offcenter_4_M2[q])
    virtual_node_degree_offcenter_5_mean_M2[q] = np.mean(virtual_node_degree_offcenter_5_M2[q])
    
    virtual_node_neighbourhood_size_center_mean_M2[q] = np.mean(virtual_node_neighbourhood_size_center_M2[q])
    virtual_node_neighbourhood_size_offcenter_1_mean_M2[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_1_M2[q])
    virtual_node_neighbourhood_size_offcenter_2_mean_M2[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_2_M2[q])
    virtual_node_neighbourhood_size_offcenter_3_mean_M2[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_3_M2[q])
    virtual_node_neighbourhood_size_offcenter_4_mean_M2[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_4_M2[q])
    virtual_node_neighbourhood_size_offcenter_5_mean_M2[q] =  np.mean(virtual_node_neighbourhood_size_offcenter_5_M2[q])
    
    virtual_node_degree_center_10pct_M2[q] = np.percentile(virtual_node_degree_center_M2[q], 10)
    virtual_node_degree_offcenter_1_10pct_M2[q] = np.percentile(virtual_node_degree_offcenter_1_M2[q], 10)
    virtual_node_degree_offcenter_2_10pct_M2[q] = np.percentile(virtual_node_degree_offcenter_2_M2[q], 10)
    virtual_node_degree_offcenter_3_10pct_M2[q] = np.percentile(virtual_node_degree_offcenter_3_M2[q], 10)
    virtual_node_degree_offcenter_4_10pct_M2[q] = np.percentile(virtual_node_degree_offcenter_4_M2[q], 10)
    virtual_node_degree_offcenter_5_10pct_M2[q] = np.percentile(virtual_node_degree_offcenter_5_M2[q], 10)

    virtual_node_degree_center_25pct_M2[q] = np.percentile(virtual_node_degree_center_M2[q], 25)
    virtual_node_degree_offcenter_1_25pct_M2[q] = np.percentile(virtual_node_degree_offcenter_1_M2[q], 25)
    virtual_node_degree_offcenter_2_25pct_M2[q] = np.percentile(virtual_node_degree_offcenter_2_M2[q], 25)
    virtual_node_degree_offcenter_3_25pct_M2[q] = np.percentile(virtual_node_degree_offcenter_3_M2[q], 25)
    virtual_node_degree_offcenter_4_25pct_M2[q] = np.percentile(virtual_node_degree_offcenter_4_M2[q], 25)
    virtual_node_degree_offcenter_5_25pct_M2[q] = np.percentile(virtual_node_degree_offcenter_5_M2[q], 25)

    virtual_node_degree_center_75pct_M2[q] = np.percentile(virtual_node_degree_center_M2[q], 75)
    virtual_node_degree_offcenter_1_75pct_M2[q] = np.percentile(virtual_node_degree_offcenter_1_M2[q], 75)
    virtual_node_degree_offcenter_2_75pct_M2[q] = np.percentile(virtual_node_degree_offcenter_2_M2[q], 75)
    virtual_node_degree_offcenter_3_75pct_M2[q] = np.percentile(virtual_node_degree_offcenter_3_M2[q], 75)
    virtual_node_degree_offcenter_4_75pct_M2[q] = np.percentile(virtual_node_degree_offcenter_4_M2[q], 75)
    virtual_node_degree_offcenter_5_75pct_M2[q] = np.percentile(virtual_node_degree_offcenter_5_M2[q], 75)
    
    virtual_node_degree_center_90pct_M2[q] = np.percentile(virtual_node_degree_center_M2[q], 90)
    virtual_node_degree_offcenter_1_90pct_M2[q] = np.percentile(virtual_node_degree_offcenter_1_M2[q], 90)
    virtual_node_degree_offcenter_2_90pct_M2[q] = np.percentile(virtual_node_degree_offcenter_2_M2[q], 90)
    virtual_node_degree_offcenter_3_90pct_M2[q] = np.percentile(virtual_node_degree_offcenter_3_M2[q], 90)
    virtual_node_degree_offcenter_4_90pct_M2[q] = np.percentile(virtual_node_degree_offcenter_4_M2[q], 90)
    virtual_node_degree_offcenter_5_90pct_M2[q] = np.percentile(virtual_node_degree_offcenter_5_M2[q], 90)
    
    virtual_neighbourhood_size_center_10pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_center_M2[q], 10)
    virtual_neighbourhood_size_offcenter_1_10pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1_M2[q], 10)
    virtual_neighbourhood_size_offcenter_2_10pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2_M2[q], 10)
    virtual_neighbourhood_size_offcenter_3_10pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3_M2[q], 10)
    virtual_neighbourhood_size_offcenter_4_10pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4_M2[q], 10)
    virtual_neighbourhood_size_offcenter_5_10pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5_M2[q], 10)
    
    virtual_neighbourhood_size_center_25pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_center_M2[q], 25)
    virtual_neighbourhood_size_offcenter_1_25pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1_M2[q], 25)
    virtual_neighbourhood_size_offcenter_2_25pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2_M2[q], 25)
    virtual_neighbourhood_size_offcenter_3_25pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3_M2[q], 25)
    virtual_neighbourhood_size_offcenter_4_25pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4_M2[q], 25)
    virtual_neighbourhood_size_offcenter_5_25pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5_M2[q], 25)  
    
    virtual_neighbourhood_size_center_75pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_center_M2[q], 75)
    virtual_neighbourhood_size_offcenter_1_75pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1_M2[q], 75)
    virtual_neighbourhood_size_offcenter_2_75pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2_M2[q], 75)
    virtual_neighbourhood_size_offcenter_3_75pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3_M2[q], 75)
    virtual_neighbourhood_size_offcenter_4_75pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4_M2[q], 75)
    virtual_neighbourhood_size_offcenter_5_75pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5_M2[q], 75) 
    
    virtual_neighbourhood_size_center_90pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_center_M2[q], 90)
    virtual_neighbourhood_size_offcenter_1_90pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_1_M2[q], 90)
    virtual_neighbourhood_size_offcenter_2_90pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_2_M2[q], 90)
    virtual_neighbourhood_size_offcenter_3_90pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_3_M2[q], 90)
    virtual_neighbourhood_size_offcenter_4_90pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_4_M2[q], 90)
    virtual_neighbourhood_size_offcenter_5_90pct_M2[q] = np.percentile(virtual_node_neighbourhood_size_offcenter_5_M2[q], 90)

# %% [markdown]
# ### Thesis plot

# %%
def adjust_lightness(color, amount=0.5):
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], max(0, min(1, amount * c[1])), c[2])

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

plt.style.use('FOLDER_LOCATION/figure.mplstyle')


mm = 1/25.4
outward = 4
color_virtual_node_degree = '#0066A2'
color_virtual_neighbourhood_size = '#EB7246'
color_text = (0, 0, 0, 0.8)
lightness_control_k = 0.33
lightness_control_V = 0.11

fig, ax = plt.subplots(2, 3, constrained_layout=True, figsize=[(157.5)*mm*1, 157.5*mm/16*8], sharex='col', sharey='row')


y_max_k = 14
y_max_v = 4
ratio = 1.25



ax[0, 0].set_aspect(1/(y_max_k*ratio))
ax[0, 0].set_ylim([0-0.04*y_max_k, y_max_k+0.04*y_max_k])

ax[0, 0].plot(prob_swap_range, virtual_node_degree_center_mean_M2, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*0), zorder=10, label=r'center')
ax[0, 0].plot(prob_swap_range, virtual_node_degree_offcenter_1_mean_M2, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*1), zorder=9, label=r'1 off-center')
ax[0, 0].plot(prob_swap_range, virtual_node_degree_offcenter_2_mean_M2, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*2), zorder=8,  label=r'2 off-center')
ax[0, 0].plot(prob_swap_range, virtual_node_degree_offcenter_3_mean_M2, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*3), zorder=7,  label=r'3 off-center')
ax[0, 0].plot(prob_swap_range, virtual_node_degree_offcenter_4_mean_M2, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*4), zorder=6,  label=r'4 off-center')
ax[0, 0].plot(prob_swap_range, virtual_node_degree_offcenter_5_mean_M2, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*5), zorder=5,  label=r'5 off-center')

ax[0, 0].plot(prob_swap_range, virtual_node_degree_mean_inf[0, :], '--', color='lightgray', linewidth=0.8, zorder = 11)
ax[0, 0].spines['left'].set_position(('outward', outward))
ax[0, 0].spines['left'].set_bounds(0, y_max_k)
ax[0, 0].set_yticks(ticks=[0, y_max_k])
ax[0, 0].set_yticks(ticks=[7], minor=True)
ax[0, 0].set_yticklabels(labels=[7], minor=True, ha='right')

ax[0, 0].spines['bottom'].set_position(('outward', outward))
ax[0, 0].spines['bottom'].set_bounds(0, 1)

ax[0, 0].set_ylabel(r'$\langle k_i(t)\rangle$', rotation=0, y=0.89, labelpad = 17.5, ha='right')

ax[1, 0].set_aspect(1/(y_max_v*ratio))
ax[1, 0].set_ylim([0-0.04*y_max_v, y_max_v+0.04*y_max_v])
ax[1, 1].set_ylim([0-0.04*y_max_v, y_max_v+0.04*y_max_v])
ax[1, 2].set_ylim([0-0.04*y_max_v, y_max_v+0.04*y_max_v])

ax[1, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_center_mean_M2, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), zorder=10,  label=r'center')
ax[1, 0].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_center_mean_M2)], np.max(virtual_node_neighbourhood_size_center_mean_M2), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), markersize=6, markeredgewidth=0)

ax[1, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_1_mean_M2, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*1), zorder=9,  label=r'1 off-center')
ax[1, 0].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_1_mean_M2)], np.max(virtual_node_neighbourhood_size_offcenter_1_mean_M2), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*1), markersize=6, markeredgewidth=0)

ax[1, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_2_mean_M2, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), zorder=8,  label=r'2 off-center')
ax[1, 0].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_2_mean_M2)], np.max(virtual_node_neighbourhood_size_offcenter_2_mean_M2), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), markersize=6, markeredgewidth=0)

ax[1, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_3_mean_M2, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*3), zorder=7,  label=r'3 off-center')
ax[1, 0].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_3_mean_M2)], np.max(virtual_node_neighbourhood_size_offcenter_3_mean_M2), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*3), markersize=6, markeredgewidth=0)

ax[1, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_4_mean_M2, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), zorder=6,  label=r'4 off-center')
ax[1, 0].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_4_mean_M2)], np.max(virtual_node_neighbourhood_size_offcenter_4_mean_M2), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), markersize=6, markeredgewidth=0)

ax[1, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_5_mean_M2, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*5), zorder=5,  label=r'5 off-center')
ax[1, 0].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_5_mean_M2)], np.max(virtual_node_neighbourhood_size_offcenter_5_mean_M2), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*5), markersize=6, markeredgewidth=0)

ax[1, 0].plot(prob_swap_range, virtual_neighbourhood_size_mean_inf[0, :], '--', color='lightgray', linewidth=0.8, zorder = 11)


ax[1, 0].spines['left'].set_position(('outward', outward))
ax[1, 0].spines['left'].set_bounds(0, y_max_v)
ax[1, 0].set_yticks(ticks=[0, y_max_v])
ax[1, 0].set_yticks(ticks=[1, 2, 3], minor=True)
ax[1, 0].set_yticklabels(labels=[1, 2, 3], minor=True, ha='right')

ax[1, 0].spines['bottom'].set_position(('outward', outward))
ax[1, 0].spines['bottom'].set_bounds(0, 1)
ax[1, 0].set_xticks(ticks=[0, 1], minor=False)
ax[1, 0].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[1, 0].set_ylabel(r'$\langle v_i(t) \rangle$', rotation=0, y=0.89, labelpad = 23, ha='right')


ax[0, 1].set_aspect(1/(y_max_k*ratio))

ax[0, 1].plot(prob_swap_range, virtual_node_degree_center_mean_M3, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*0), zorder=10, label=r'center')
ax[0, 1].plot(prob_swap_range, virtual_node_degree_offcenter_1_mean_M3, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*1), zorder=9, label=r'1 off-center')
ax[0, 1].plot(prob_swap_range, virtual_node_degree_offcenter_2_mean_M3, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*2), zorder=8,  label=r'2 off-center')
ax[0, 1].plot(prob_swap_range, virtual_node_degree_offcenter_3_mean_M3, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*3), zorder=7,  label=r'3 off-center')
ax[0, 1].plot(prob_swap_range, virtual_node_degree_offcenter_4_mean_M3, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*4), zorder=6,  label=r'4 off-center')
ax[0, 1].plot(prob_swap_range, virtual_node_degree_offcenter_5_mean_M3, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*5), zorder=5,  label=r'5 off-center')

ax[0, 1].plot(prob_swap_range, virtual_node_degree_mean_inf[1, :], '--', color='lightgray', linewidth=0.8, zorder = 11)
ax[0, 1].spines['left'].set_position(('outward', outward))
ax[0, 1].spines['left'].set_bounds(0, y_max_k)


ax[0, 1].spines['bottom'].set_position(('outward', outward))
ax[0, 1].spines['bottom'].set_bounds(0, 1)

ax[1, 1].set_aspect(1/(y_max_v*ratio))


ax[1, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_center_mean_M3, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), zorder=10,  label=r'center')
ax[1, 1].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_center_mean_M3)], np.max(virtual_node_neighbourhood_size_center_mean_M3), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), markersize=6, markeredgewidth=0)

ax[1, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_1_mean_M3, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*1), zorder=9,  label=r'1 off-center')
ax[1, 1].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_1_mean_M3)], np.max(virtual_node_neighbourhood_size_offcenter_1_mean_M3), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*1), markersize=6, markeredgewidth=0)

ax[1, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_2_mean_M3, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), zorder=8,  label=r'2 off-center')
ax[1, 1].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_2_mean_M3)], np.max(virtual_node_neighbourhood_size_offcenter_2_mean_M3), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), markersize=6, markeredgewidth=0)

ax[1, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_3_mean_M3, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*3), zorder=7,  label=r'3 off-center')
ax[1, 1].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_3_mean_M3)], np.max(virtual_node_neighbourhood_size_offcenter_3_mean_M3), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*3), markersize=6, markeredgewidth=0)

ax[1, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_4_mean_M3, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), zorder=6,  label=r'4 off-center')
ax[1, 1].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_4_mean_M3)], np.max(virtual_node_neighbourhood_size_offcenter_4_mean_M3), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), markersize=6, markeredgewidth=0)

ax[1, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_5_mean_M3, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*5), zorder=5,  label=r'5 off-center')
ax[1, 1].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_5_mean_M3)], np.max(virtual_node_neighbourhood_size_offcenter_5_mean_M3), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*5), markersize=6, markeredgewidth=0)

ax[1, 1].plot(prob_swap_range, virtual_neighbourhood_size_mean_inf[1, :], '--', color='lightgray', linewidth=0.8, zorder = 11)


ax[1, 1].spines['left'].set_position(('outward', outward))
ax[1, 1].spines['left'].set_bounds(0, y_max_v)
ax[1, 1].set_yticks(ticks=[0, y_max_v])

ax[1, 1].spines['bottom'].set_position(('outward', outward))
ax[1, 1].spines['bottom'].set_bounds(0, 1)
ax[1, 1].set_xticks(ticks=[0, 1], minor=False)
ax[1, 1].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 2].set_ylim([0-0.04*y_max_k, y_max_k+0.04*y_max_k])

ax[0, 2].plot(prob_swap_range, virtual_node_degree_center_mean, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*0), zorder=10, label=r'center')
ax[0, 2].plot(prob_swap_range, virtual_node_degree_offcenter_1_mean, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*1), zorder=9, label=r'1 off-center')
ax[0, 2].plot(prob_swap_range, virtual_node_degree_offcenter_2_mean, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*2), zorder=8,  label=r'2 off-center')
ax[0, 2].plot(prob_swap_range, virtual_node_degree_offcenter_3_mean, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*3), zorder=7,  label=r'3 off-center')
ax[0, 2].plot(prob_swap_range, virtual_node_degree_offcenter_4_mean, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*4), zorder=6,  label=r'4 off-center')
ax[0, 2].plot(prob_swap_range, virtual_node_degree_offcenter_5_mean, '-', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*5), zorder=5,  label=r'5 off-center')

ax[0, 2].plot(prob_swap_range, virtual_node_degree_mean_inf[2, :], '--', color='lightgray', linewidth=0.8, zorder = 11)


ax[0, 2].spines['left'].set_position(('outward', outward))
ax[0, 2].spines['left'].set_bounds(0, 14)
ax[0, 2].set_yticks(ticks=[0, 14])
ax[0, 2].set_yticks(ticks=[7], minor=True)
ax[0, 2].set_yticklabels(labels=[7], minor=True, ha='right')

ax[0, 2].spines['bottom'].set_position(('outward', outward))
ax[0, 2].spines['bottom'].set_bounds(0, 1)

ax[0, 2].plot([1.1, 1.1], [0, 14], '-', color='gainsboro')

for i in range(11):
    ax[0, 2].plot(1.1, i*14/10, 'o', color=adjust_lightness(color_virtual_node_degree, 0.9+lightness_control_k*np.abs(i-5)), markersize=4)
    
ax[0, 2].text(1.15, 7, r'Centre', color=color_text, fontsize=10, ha='left', va='center_baseline')
ax[0, 2].text(1.15, 14, r'Edge', color=color_text, fontsize=10, ha='left', va='center_baseline')
ax[0, 2].text(1.15, 0, r'Edge', color=color_text, fontsize=10, ha='left', va='center_baseline')    

ax[1, 2].set_aspect(1/(y_max_v*ratio))
    
ax[1, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_center_mean, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), zorder=10,  label=r'center')
ax[1, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_center_mean)], np.max(virtual_node_neighbourhood_size_center_mean), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), markersize=6, markeredgewidth=0)

ax[1, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_1_mean, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*1), zorder=9,  label=r'1 off-center')
ax[1, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_1_mean)], np.max(virtual_node_neighbourhood_size_offcenter_1_mean), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*1), markersize=6, markeredgewidth=0)

ax[1, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_2_mean, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), zorder=8,  label=r'2 off-center')
ax[1, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_2_mean)], np.max(virtual_node_neighbourhood_size_offcenter_2_mean), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), markersize=6, markeredgewidth=0)

ax[1, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_3_mean, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*3), zorder=7,  label=r'3 off-center')
ax[1, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_3_mean)], np.max(virtual_node_neighbourhood_size_offcenter_3_mean), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*3), markersize=6, markeredgewidth=0)

ax[1, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_4_mean, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), zorder=6,  label=r'4 off-center')
ax[1, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_4_mean)], np.max(virtual_node_neighbourhood_size_offcenter_4_mean), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), markersize=6, markeredgewidth=0)

ax[1, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_5_mean, '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*5), zorder=5,  label=r'5 off-center')
ax[1, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_5_mean)], np.max(virtual_node_neighbourhood_size_offcenter_5_mean), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*5), markersize=6, markeredgewidth=0)

ax[1, 2].plot(prob_swap_range, virtual_neighbourhood_size_mean_inf[2, :], '--', color='lightgray', linewidth=0.8, zorder = 11)

ax[1, 2].spines['left'].set_position(('outward', outward))
ax[1, 2].spines['left'].set_bounds(0, 4)
ax[1, 2].set_yticks(ticks=[0, 4])

ax[1, 2].spines['bottom'].set_position(('outward', outward))
ax[1, 2].spines['bottom'].set_bounds(0, 1)
ax[1, 2].set_xticks(ticks=[0, 1], minor=False)
ax[1, 2].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[1, 2].plot([1.1, 1.1], [0, 4], '-', color='gainsboro')

for i in range(11):
    ax[1, 2].plot(1.1, i*4/10, 'o', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*np.abs(i-5)), markersize=4)
    
    
ax[1, 2].text(1.15, 2, r'Centre', color=color_text, fontsize=10, ha='left', va='center_baseline')
ax[1, 2].text(1.15, 4, r'Edge', color=color_text, fontsize=10, ha='left', va='center_baseline')
ax[1, 2].text(1.15, 0, r'Edge', color=color_text, fontsize=10, ha='left', va='center_baseline')

ax[1, 2].text(0.25, 0.2, r'Infinite chain', color='darkgray', fontsize=9)
ax[0, 0].set_title(r'$M=2$', color=color_text, fontsize=10)
ax[0, 1].set_title(r'$M=3$', color=color_text, fontsize=10)
ax[0, 2].set_title(r'$M=4$', color=color_text, fontsize=10)

fig.supxlabel(r'Swap probability $q$', x=0.525,  color=color_text, fontsize=10)

# fig.savefig('FOLDER_LOCATION/Finite networks/sweep_prob_swap_chain.pdf', bbox_inches = 'tight', pad_inches=0*mm)
# Out:
# Text(0.525, 0.01, 'Swap probability $q$')

# %%
print(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_center_mean)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_1_mean)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_2_mean)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_3_mean)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_4_mean)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_5_mean)])
# Out:
# 0.18 0.16 0.16 0.15 0.14 0.52

# %%
print(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_center_mean_M3)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_1_mean_M3)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_2_mean_M3)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_3_mean_M3)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_4_mean_M3)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_5_mean_M3)])
# Out:
# 0.15 0.17 0.16 0.15 0.14 0.43

# %%
print(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_center_mean_M2)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_1_mean_M2)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_2_mean_M2)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_3_mean_M2)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_4_mean_M2)],
prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_5_mean_M2)])
# Out:
# 0.13 0.13 0.15 0.14 0.13 0.36

# %% [markdown]
# ### Distribution plot

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

plt.style.use('FOLDER_LOCATION/figure.mplstyle')


mm = 1/25.4
outward = 4
color_virtual_node_degree = '#0066A2'
color_virtual_neighbourhood_size = '#EB7246'
color_text = (0, 0, 0, 0.8)
lightness_control_k = 0.42
lightness_control_V = 0.14

fig, ax = plt.subplots(12, 3, constrained_layout=True, figsize=[(157.5)*mm*0.6, 157.5*mm*np.sqrt(2)*1.1], sharex='col', sharey='row')


y_max_k = 14
y_max_v = 6
ratio = 1.25

ax[0, 0].plot(prob_swap_range, virtual_node_degree_center_mean_M2, '-', color=color_virtual_node_degree, zorder=10, label=r'center')
ax[0, 0].fill_between(prob_swap_range, virtual_node_degree_center_25pct_M2, virtual_node_degree_center_75pct_M2, facecolor=color_virtual_node_degree, alpha=0.5)
ax[0, 0].fill_between(prob_swap_range, virtual_node_degree_center_10pct_M2, virtual_node_degree_center_25pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)
ax[0, 0].fill_between(prob_swap_range, virtual_node_degree_center_75pct_M2, virtual_node_degree_center_90pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)

ax[2, 0].plot(prob_swap_range, virtual_node_degree_offcenter_1_mean_M2, '-', color=color_virtual_node_degree, zorder=9, label=r'1 off-center')
ax[2, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_1_25pct_M2, virtual_node_degree_offcenter_1_75pct_M2, facecolor=color_virtual_node_degree, alpha=0.5)
ax[2, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_1_10pct_M2, virtual_node_degree_offcenter_1_25pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)
ax[2, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_1_75pct_M2, virtual_node_degree_offcenter_1_90pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)

ax[4, 0].plot(prob_swap_range, virtual_node_degree_offcenter_2_mean_M2, '-', color=color_virtual_node_degree, zorder=8,  label=r'2 off-center')
ax[4, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_2_25pct_M2, virtual_node_degree_offcenter_2_75pct_M2, facecolor=color_virtual_node_degree, alpha=0.5)
ax[4, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_2_10pct_M2, virtual_node_degree_offcenter_2_25pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)
ax[4, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_2_75pct_M2, virtual_node_degree_offcenter_2_90pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)

ax[6, 0].plot(prob_swap_range, virtual_node_degree_offcenter_3_mean_M2, '-', color=color_virtual_node_degree, zorder=7,  label=r'3 off-center')
ax[6, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_3_25pct_M2, virtual_node_degree_offcenter_3_75pct_M2, facecolor=color_virtual_node_degree, alpha=0.5)
ax[6, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_3_10pct_M2, virtual_node_degree_offcenter_3_25pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)
ax[6, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_3_75pct_M2, virtual_node_degree_offcenter_3_90pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)

ax[8, 0].plot(prob_swap_range, virtual_node_degree_offcenter_4_mean_M2, '-', color=color_virtual_node_degree, zorder=6,  label=r'4 off-center')
ax[8, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_4_25pct_M2, virtual_node_degree_offcenter_4_75pct_M2, facecolor=color_virtual_node_degree, alpha=0.5)
ax[8, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_4_10pct_M2, virtual_node_degree_offcenter_4_25pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)
ax[8, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_4_75pct_M2, virtual_node_degree_offcenter_4_90pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)

ax[10, 0].plot(prob_swap_range, virtual_node_degree_offcenter_5_mean_M3, '-', color=color_virtual_node_degree, zorder=5,  label=r'5 off-center')
ax[10, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_5_25pct_M2, virtual_node_degree_offcenter_5_75pct_M2, facecolor=color_virtual_node_degree, alpha=0.5)
ax[10, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_5_10pct_M2, virtual_node_degree_offcenter_5_25pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)
ax[10, 0].fill_between(prob_swap_range, virtual_node_degree_offcenter_5_75pct_M2, virtual_node_degree_offcenter_5_90pct_M2, facecolor=color_virtual_node_degree, alpha=0.2)

for i in range(6):
    ax[2*i, 0].set_aspect(1/(y_max_k*ratio))
    ax[2*i, 0].set_ylim([0-0.06*y_max_k, y_max_k+0.06*y_max_k])
    ax[2*i, 0].spines['left'].set_position(('outward', outward))
    ax[2*i, 0].spines['left'].set_bounds(0, y_max_k)
    ax[2*i, 0].set_yticks(ticks=[0, y_max_k])
    ax[2*i, 0].set_yticks(ticks=[7], minor=True)
    ax[2*i, 0].set_yticklabels(labels=[7], minor=True, ha='right')

    ax[2*i, 0].spines['bottom'].set_position(('outward', outward))
    ax[2*i, 0].spines['bottom'].set_bounds(0, 1)

    ax[2*i, 0].set_ylabel(r'$\langle k_i(t)\rangle$', rotation=0, y=0.82, labelpad = 17.5, ha='right')

ax[1, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_center_mean_M2, '-', color=color_virtual_neighbourhood_size, zorder=10,  label=r'center')
# ax[1, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_center_mean)], np.max(virtual_node_neighbourhood_size_center_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[1, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_center_25pct_M2, virtual_neighbourhood_size_center_75pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[1, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_center_10pct_M2, virtual_neighbourhood_size_center_25pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[1, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_center_75pct_M2, virtual_neighbourhood_size_center_90pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[3, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_1_mean_M2, '-', color=color_virtual_neighbourhood_size, zorder=9,  label=r'1 off-center')
# ax[3, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_1_mean)], np.max(virtual_node_neighbourhood_size_offcenter_1_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[3, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_1_25pct_M2, virtual_neighbourhood_size_offcenter_1_75pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[3, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_1_10pct_M2, virtual_neighbourhood_size_offcenter_1_25pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[3, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_1_75pct_M2, virtual_neighbourhood_size_offcenter_1_90pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[5, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_2_mean_M2, '-', color=color_virtual_neighbourhood_size, zorder=8,  label=r'2 off-center')
# ax[5, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_2_mean)], np.max(virtual_node_neighbourhood_size_offcenter_2_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[5, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_2_25pct_M2, virtual_neighbourhood_size_offcenter_2_75pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[5, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_2_10pct_M2, virtual_neighbourhood_size_offcenter_2_25pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[5, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_2_75pct_M2, virtual_neighbourhood_size_offcenter_2_90pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[7, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_3_mean_M2, '-', color=color_virtual_neighbourhood_size, zorder=7,  label=r'3 off-center')
# ax[7, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_3_mean)], np.max(virtual_node_neighbourhood_size_offcenter_3_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[7, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_3_25pct_M2, virtual_neighbourhood_size_offcenter_3_75pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[7, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_3_10pct_M2, virtual_neighbourhood_size_offcenter_3_25pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[7, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_3_75pct_M2, virtual_neighbourhood_size_offcenter_3_90pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[9, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_4_mean_M2, '-', color=color_virtual_neighbourhood_size, zorder=6,  label=r'4 off-center')
# ax[9, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_4_mean)], np.max(virtual_node_neighbourhood_size_offcenter_4_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[9, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_4_25pct_M2, virtual_neighbourhood_size_offcenter_4_75pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[9, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_4_10pct_M2, virtual_neighbourhood_size_offcenter_4_25pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[9, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_4_75pct_M2, virtual_neighbourhood_size_offcenter_4_90pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[11, 0].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_5_mean_M2, '-', color=color_virtual_neighbourhood_size, zorder=5,  label=r'5 off-center')
# ax[11, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_5_mean)], np.max(virtual_node_neighbourhood_size_offcenter_5_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[11, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_5_25pct_M2, virtual_neighbourhood_size_offcenter_5_75pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[11, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_5_10pct_M2, virtual_neighbourhood_size_offcenter_5_25pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[11, 0].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_5_75pct_M2, virtual_neighbourhood_size_offcenter_5_90pct_M2, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

for i in range(6):
    ax[2*i+1, 0].set_aspect(1/(y_max_v*ratio))
    ax[2*i+1, 0].set_ylim([0-0.06*y_max_v, y_max_v+0.06*y_max_v])
    
    ax[2*i+1, 0].spines['left'].set_position(('outward', outward))
    ax[2*i+1, 0].spines['left'].set_bounds(0, y_max_v)
    ax[2*i+1, 0].set_yticks(ticks=[0, y_max_v])
    ax[2*i+1, 0].set_yticks(ticks=[2, 4], minor=True)
    ax[2*i+1, 0].set_yticklabels(labels=[2, 4], minor=True, ha='right')

    ax[2*i+1, 0].spines['bottom'].set_position(('outward', outward))
    ax[2*i+1, 0].spines['bottom'].set_bounds(0, 1)
    ax[2*i+1, 0].set_xticks(ticks=[0, 1], minor=False)
    ax[2*i+1, 0].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

    ax[2*i+1, 0].set_ylabel(r'$\langle v_i(t) \rangle$', rotation=0, y=0.82, labelpad = 23, ha='right')

ax[0, 1].plot(prob_swap_range, virtual_node_degree_center_mean_M3, '-', color=color_virtual_node_degree, zorder=10, label=r'center')
ax[0, 1].fill_between(prob_swap_range, virtual_node_degree_center_25pct_M3, virtual_node_degree_center_75pct_M3, facecolor=color_virtual_node_degree, alpha=0.5)
ax[0, 1].fill_between(prob_swap_range, virtual_node_degree_center_10pct_M3, virtual_node_degree_center_25pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)
ax[0, 1].fill_between(prob_swap_range, virtual_node_degree_center_75pct_M3, virtual_node_degree_center_90pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)

ax[2, 1].plot(prob_swap_range, virtual_node_degree_offcenter_1_mean_M3, '-', color=color_virtual_node_degree, zorder=9, label=r'1 off-center')
ax[2, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_1_25pct_M3, virtual_node_degree_offcenter_1_75pct_M3, facecolor=color_virtual_node_degree, alpha=0.5)
ax[2, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_1_10pct_M3, virtual_node_degree_offcenter_1_25pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)
ax[2, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_1_75pct_M3, virtual_node_degree_offcenter_1_90pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)

ax[4, 1].plot(prob_swap_range, virtual_node_degree_offcenter_2_mean_M3, '-', color=color_virtual_node_degree, zorder=8,  label=r'2 off-center')
ax[4, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_2_25pct_M3, virtual_node_degree_offcenter_2_75pct_M3, facecolor=color_virtual_node_degree, alpha=0.5)
ax[4, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_2_10pct_M3, virtual_node_degree_offcenter_2_25pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)
ax[4, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_2_75pct_M3, virtual_node_degree_offcenter_2_90pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)

ax[6, 1].plot(prob_swap_range, virtual_node_degree_offcenter_3_mean_M3, '-', color=color_virtual_node_degree, zorder=7,  label=r'3 off-center')
ax[6, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_3_25pct_M3, virtual_node_degree_offcenter_3_75pct_M3, facecolor=color_virtual_node_degree, alpha=0.5)
ax[6, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_3_10pct_M3, virtual_node_degree_offcenter_3_25pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)
ax[6, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_3_75pct_M3, virtual_node_degree_offcenter_3_90pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)

ax[8, 1].plot(prob_swap_range, virtual_node_degree_offcenter_4_mean_M3, '-', color=color_virtual_node_degree, zorder=6,  label=r'4 off-center')
ax[8, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_4_25pct_M3, virtual_node_degree_offcenter_4_75pct_M3, facecolor=color_virtual_node_degree, alpha=0.5)
ax[8, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_4_10pct_M3, virtual_node_degree_offcenter_4_25pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)
ax[8, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_4_75pct_M3, virtual_node_degree_offcenter_4_90pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)

ax[10, 1].plot(prob_swap_range, virtual_node_degree_offcenter_5_mean_M3, '-', color=color_virtual_node_degree, zorder=5,  label=r'5 off-center')
ax[10, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_5_25pct_M3, virtual_node_degree_offcenter_5_75pct_M3, facecolor=color_virtual_node_degree, alpha=0.5)
ax[10, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_5_10pct_M3, virtual_node_degree_offcenter_5_25pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)
ax[10, 1].fill_between(prob_swap_range, virtual_node_degree_offcenter_5_75pct_M3, virtual_node_degree_offcenter_5_90pct_M3, facecolor=color_virtual_node_degree, alpha=0.2)

for i in range(6):
    ax[2*i, 1].set_aspect(1/(y_max_k*ratio))
    ax[2*i, 1].set_ylim([0-0.06*y_max_k, y_max_k+0.06*y_max_k])
    ax[2*i, 1].spines['left'].set_position(('outward', outward))
    ax[2*i, 1].spines['left'].set_bounds(0, y_max_k)
    ax[2*i, 1].set_yticks(ticks=[0, y_max_k])
    ax[2*i, 1].set_yticks(ticks=[7], minor=True)
    ax[2*i, 1].set_yticklabels(labels=[7], minor=True, ha='right')

    ax[2*i, 1].spines['bottom'].set_position(('outward', outward))
    ax[2*i, 1].spines['bottom'].set_bounds(0, 1)

ax[1, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_center_mean_M3, '-', color=color_virtual_neighbourhood_size, zorder=10,  label=r'center')
# ax[1, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_center_mean)], np.max(virtual_node_neighbourhood_size_center_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[1, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_center_25pct_M3, virtual_neighbourhood_size_center_75pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[1, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_center_10pct_M3, virtual_neighbourhood_size_center_25pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[1, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_center_75pct_M3, virtual_neighbourhood_size_center_90pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[3, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_1_mean_M3, '-', color=color_virtual_neighbourhood_size, zorder=9,  label=r'1 off-center')
# ax[3, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_1_mean)], np.max(virtual_node_neighbourhood_size_offcenter_1_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[3, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_1_25pct_M3, virtual_neighbourhood_size_offcenter_1_75pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[3, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_1_10pct_M3, virtual_neighbourhood_size_offcenter_1_25pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[3, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_1_75pct_M3, virtual_neighbourhood_size_offcenter_1_90pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[5, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_2_mean_M3, '-', color=color_virtual_neighbourhood_size, zorder=8,  label=r'2 off-center')
# ax[5, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_2_mean)], np.max(virtual_node_neighbourhood_size_offcenter_2_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[5, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_2_25pct_M3, virtual_neighbourhood_size_offcenter_2_75pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[5, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_2_10pct_M3, virtual_neighbourhood_size_offcenter_2_25pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[5, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_2_75pct_M3, virtual_neighbourhood_size_offcenter_2_90pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[7, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_3_mean_M3, '-', color=color_virtual_neighbourhood_size, zorder=7,  label=r'3 off-center')
# ax[7, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_3_mean)], np.max(virtual_node_neighbourhood_size_offcenter_3_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[7, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_3_25pct_M3, virtual_neighbourhood_size_offcenter_3_75pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[7, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_3_10pct_M3, virtual_neighbourhood_size_offcenter_3_25pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[7, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_3_75pct_M3, virtual_neighbourhood_size_offcenter_3_90pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[9, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_4_mean_M3, '-', color=color_virtual_neighbourhood_size, zorder=6,  label=r'4 off-center')
# ax[9, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_4_mean)], np.max(virtual_node_neighbourhood_size_offcenter_4_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[9, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_4_25pct_M3, virtual_neighbourhood_size_offcenter_4_75pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[9, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_4_10pct_M3, virtual_neighbourhood_size_offcenter_4_25pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[9, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_4_75pct_M3, virtual_neighbourhood_size_offcenter_4_90pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[11, 1].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_5_mean_M3, '-', color=color_virtual_neighbourhood_size, zorder=5,  label=r'5 off-center')
# ax[11, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_5_mean)], np.max(virtual_node_neighbourhood_size_offcenter_5_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[11, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_5_25pct_M3, virtual_neighbourhood_size_offcenter_5_75pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[11, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_5_10pct_M3, virtual_neighbourhood_size_offcenter_5_25pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[11, 1].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_5_75pct_M3, virtual_neighbourhood_size_offcenter_5_90pct_M3, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

for i in range(6):
    ax[2*i+1, 1].set_aspect(1/(y_max_v*ratio))
    ax[2*i+1, 1].set_ylim([0-0.06*y_max_v, y_max_v+0.06*y_max_v])
    
    ax[2*i+1, 1].spines['left'].set_position(('outward', outward))
    ax[2*i+1, 1].spines['left'].set_bounds(0, y_max_v)
    ax[2*i+1, 1].set_yticks(ticks=[0, y_max_v])
    ax[2*i+1, 1].set_yticks(ticks=[2, 4], minor=True)
    ax[2*i+1, 1].set_yticklabels(labels=[2, 4], minor=True, ha='right')

    ax[2*i+1, 1].spines['bottom'].set_position(('outward', outward))
    ax[2*i+1, 1].spines['bottom'].set_bounds(0, 1)
    ax[2*i+1, 1].set_xticks(ticks=[0, 1], minor=False)
    ax[2*i+1, 1].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 2].plot(prob_swap_range, virtual_node_degree_center_mean, '-', color=color_virtual_node_degree, zorder=10, label=r'center')
ax[0, 2].fill_between(prob_swap_range, virtual_node_degree_center_25pct, virtual_node_degree_center_75pct, facecolor=color_virtual_node_degree, alpha=0.5)
ax[0, 2].fill_between(prob_swap_range, virtual_node_degree_center_10pct, virtual_node_degree_center_25pct, facecolor=color_virtual_node_degree, alpha=0.2)
ax[0, 2].fill_between(prob_swap_range, virtual_node_degree_center_75pct, virtual_node_degree_center_90pct, facecolor=color_virtual_node_degree, alpha=0.2)

ax[2, 2].plot(prob_swap_range, virtual_node_degree_offcenter_1_mean, '-', color=color_virtual_node_degree, zorder=9, label=r'1 off-center')
ax[2, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_1_25pct, virtual_node_degree_offcenter_1_75pct, facecolor=color_virtual_node_degree, alpha=0.5)
ax[2, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_1_10pct, virtual_node_degree_offcenter_1_25pct, facecolor=color_virtual_node_degree, alpha=0.2)
ax[2, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_1_75pct, virtual_node_degree_offcenter_1_90pct, facecolor=color_virtual_node_degree, alpha=0.2)

ax[4, 2].plot(prob_swap_range, virtual_node_degree_offcenter_2_mean, '-', color=color_virtual_node_degree, zorder=8,  label=r'2 off-center')
ax[4, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_2_25pct, virtual_node_degree_offcenter_2_75pct, facecolor=color_virtual_node_degree, alpha=0.5)
ax[4, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_2_10pct, virtual_node_degree_offcenter_2_25pct, facecolor=color_virtual_node_degree, alpha=0.2)
ax[4, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_2_75pct, virtual_node_degree_offcenter_2_90pct, facecolor=color_virtual_node_degree, alpha=0.2)

ax[6, 2].plot(prob_swap_range, virtual_node_degree_offcenter_3_mean, '-', color=color_virtual_node_degree, zorder=7,  label=r'3 off-center')
ax[6, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_3_25pct, virtual_node_degree_offcenter_3_75pct, facecolor=color_virtual_node_degree, alpha=0.5)
ax[6, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_3_10pct, virtual_node_degree_offcenter_3_25pct, facecolor=color_virtual_node_degree, alpha=0.2)
ax[6, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_3_75pct, virtual_node_degree_offcenter_3_90pct, facecolor=color_virtual_node_degree, alpha=0.2)

ax[8, 2].plot(prob_swap_range, virtual_node_degree_offcenter_4_mean, '-', color=color_virtual_node_degree, zorder=6,  label=r'4 off-center')
ax[8, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_4_25pct, virtual_node_degree_offcenter_4_75pct, facecolor=color_virtual_node_degree, alpha=0.5)
ax[8, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_4_10pct, virtual_node_degree_offcenter_4_25pct, facecolor=color_virtual_node_degree, alpha=0.2)
ax[8, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_4_75pct, virtual_node_degree_offcenter_4_90pct, facecolor=color_virtual_node_degree, alpha=0.2)

ax[10, 2].plot(prob_swap_range, virtual_node_degree_offcenter_5_mean, '-', color=color_virtual_node_degree, zorder=5,  label=r'5 off-center')
ax[10, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_5_25pct, virtual_node_degree_offcenter_5_75pct, facecolor=color_virtual_node_degree, alpha=0.5)
ax[10, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_5_10pct, virtual_node_degree_offcenter_5_25pct, facecolor=color_virtual_node_degree, alpha=0.2)
ax[10, 2].fill_between(prob_swap_range, virtual_node_degree_offcenter_5_75pct, virtual_node_degree_offcenter_5_90pct, facecolor=color_virtual_node_degree, alpha=0.2)


for i in range(6):
    ax[2*i, 2].set_aspect(1/(y_max_k*ratio))
    ax[2*i, 2].set_ylim([0-0.06*y_max_k, y_max_k+0.06*y_max_k])
    ax[2*i, 2].spines['left'].set_position(('outward', outward))
    ax[2*i, 2].spines['left'].set_bounds(0, y_max_k)
    ax[2*i, 2].set_yticks(ticks=[0, y_max_k])
    ax[2*i, 2].set_yticks(ticks=[7], minor=True)
    ax[2*i, 2].set_yticklabels(labels=[7], minor=True, ha='right')

    ax[2*i, 2].spines['bottom'].set_position(('outward', outward))
    ax[2*i, 2].spines['bottom'].set_bounds(0, 1)
    

ax[1, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_center_mean, '-', color=color_virtual_neighbourhood_size, zorder=10,  label=r'center')
# ax[1, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_center_mean)], np.max(virtual_node_neighbourhood_size_center_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[1, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_center_25pct, virtual_neighbourhood_size_center_75pct, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[1, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_center_10pct, virtual_neighbourhood_size_center_25pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[1, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_center_75pct, virtual_neighbourhood_size_center_90pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[3, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_1_mean, '-', color=color_virtual_neighbourhood_size, zorder=9,  label=r'1 off-center')
# ax[3, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_1_mean)], np.max(virtual_node_neighbourhood_size_offcenter_1_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[3, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_1_25pct, virtual_neighbourhood_size_offcenter_1_75pct, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[3, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_1_10pct, virtual_neighbourhood_size_offcenter_1_25pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[3, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_1_75pct, virtual_neighbourhood_size_offcenter_1_90pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[5, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_2_mean, '-', color=color_virtual_neighbourhood_size, zorder=8,  label=r'2 off-center')
# ax[5, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_2_mean)], np.max(virtual_node_neighbourhood_size_offcenter_2_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[5, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_2_25pct, virtual_neighbourhood_size_offcenter_2_75pct, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[5, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_2_10pct, virtual_neighbourhood_size_offcenter_2_25pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[5, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_2_75pct, virtual_neighbourhood_size_offcenter_2_90pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[7, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_3_mean, '-', color=color_virtual_neighbourhood_size, zorder=7,  label=r'3 off-center')
# ax[7, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_3_mean)], np.max(virtual_node_neighbourhood_size_offcenter_3_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[7, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_3_25pct, virtual_neighbourhood_size_offcenter_3_75pct, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[7, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_3_10pct, virtual_neighbourhood_size_offcenter_3_25pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[7, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_3_75pct, virtual_neighbourhood_size_offcenter_3_90pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[9, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_4_mean, '-', color=color_virtual_neighbourhood_size, zorder=6,  label=r'4 off-center')
# ax[9, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_4_mean)], np.max(virtual_node_neighbourhood_size_offcenter_4_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[9, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_4_25pct, virtual_neighbourhood_size_offcenter_4_75pct, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[9, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_4_10pct, virtual_neighbourhood_size_offcenter_4_25pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[9, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_4_75pct, virtual_neighbourhood_size_offcenter_4_90pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

ax[11, 2].plot(prob_swap_range, virtual_node_neighbourhood_size_offcenter_5_mean, '-', color=color_virtual_neighbourhood_size, zorder=5,  label=r'5 off-center')
# ax[11, 2].plot(prob_swap_range[np.argmax(virtual_node_neighbourhood_size_offcenter_5_mean)], np.max(virtual_node_neighbourhood_size_offcenter_5_mean), '.', color=color_virtual_neighbourhood_size, markersize=6, markeredgewidth=0)
ax[11, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_5_25pct, virtual_neighbourhood_size_offcenter_5_75pct, facecolor=color_virtual_neighbourhood_size, alpha=0.5)
ax[11, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_5_10pct, virtual_neighbourhood_size_offcenter_5_25pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)
ax[11, 2].fill_between(prob_swap_range, virtual_neighbourhood_size_offcenter_5_75pct, virtual_neighbourhood_size_offcenter_5_90pct, facecolor=color_virtual_neighbourhood_size, alpha=0.2)

for i in range(6):
    ax[2*i+1, 2].set_aspect(1/(y_max_v*ratio))
    ax[2*i+1, 2].set_ylim([0-0.06*y_max_v, y_max_v+0.06*y_max_v])
    
    ax[2*i+1, 2].spines['left'].set_position(('outward', outward))
    ax[2*i+1, 2].spines['left'].set_bounds(0, y_max_v)
    ax[2*i+1, 2].set_yticks(ticks=[0, y_max_v])
    ax[2*i+1, 2].set_yticks(ticks=[2, 4], minor=True)
    ax[2*i+1, 2].set_yticklabels(labels=[2, 4], minor=True, ha='right')

    ax[2*i+1, 2].spines['bottom'].set_position(('outward', outward))
    ax[2*i+1, 2].spines['bottom'].set_bounds(0, 1)
    ax[2*i+1, 2].set_xticks(ticks=[0, 1], minor=False)
    ax[2*i+1, 2].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)


for i in range(11):
    for j in range(6):
        ax[2*j, 2].plot([1.1, 1.1], [0, 14], '-', color='gainsboro', linewidth=0.6)
        ax[2*j, 2].plot(1.1, i*14/10, 'o', color='gainsboro', markersize=2)
        ax[2*j, 2].plot(1.1, (5-j)*14/10, 'o', color=color_virtual_node_degree, markersize=2)
        ax[2*j, 2].plot(1.1, (5+j)*14/10, 'o', color=color_virtual_node_degree, markersize=2)

for i in range(11):
    for j in range(6):
        ax[2*j+1, 2].plot([1.1, 1.1], [0, 6], '-', color='gainsboro', linewidth=0.6)
        ax[2*j+1, 2].plot(1.1, i*6/10, 'o', color='gainsboro', markersize=2)
        ax[2*j+1, 2].plot(1.1, (5-j)*6/10, 'o', color=color_virtual_neighbourhood_size, markersize=2)
        ax[2*j+1, 2].plot(1.1, (5+j)*6/10, 'o', color=color_virtual_neighbourhood_size, markersize=2)

ax[0, 0].set_title(r'$M=2$', color=color_text, fontsize=10)
ax[0, 1].set_title(r'$M=3$', color=color_text, fontsize=10)
ax[0, 2].set_title(r'$M=4$', color=color_text, fontsize=10)

fig.supxlabel(r'Swap probability $q$', x=0.6,  color=color_text, fontsize=10)

ax[1, 1].text(0.40, 3.9, r'25--75\%', ha='left', color=color_virtual_neighbourhood_size, alpha=0.6, fontsize=9)
ax[1, 1].text(0.34, 5, r'10--90\%', ha='left', color=color_virtual_neighbourhood_size, alpha=0.3, fontsize=9)
ax[1, 1].plot([0.2, 0.3], [4.7, 5.5], '-', color='gray', linewidth=0.6, zorder=3)
ax[1, 1].plot([0.27, 0.37], [3.6, 4.4], '-', color='gray', linewidth=0.6, zorder=3)

# fig.savefig('FOLDER_LOCATION/sweep_prob_swap_finite_chain_distribution.pdf', bbox_inches = 'tight', pad_inches=0*mm)
