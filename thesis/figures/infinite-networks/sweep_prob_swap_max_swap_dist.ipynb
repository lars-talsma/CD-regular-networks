# %%
import numpy as np
prob_swap_sweep_size = 100+1
prob_swap_range = np.arange(0, prob_swap_sweep_size)/(prob_swap_sweep_size-1)
max_link_dist_range = [0, 1, 2, 4, 7]

results = np.load('FOLDER_LOCATION/Infinite networks/Infinite chain/sweep_prob_swap_max_link_dist/results.npy')

virtual_node_degree_mean_kp2 = [results[i*len(prob_swap_range)+j][0] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_mean_kp2 = [results[i*len(prob_swap_range)+j][2] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]

virtual_node_degree_mean_kp2 = np.reshape(virtual_node_degree_mean_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_mean_kp2 = np.reshape(virtual_neighbourhood_size_mean_kp2, (len(max_link_dist_range), len(prob_swap_range)))

virtual_node_degree_10pct_kp2 = [results[i*len(prob_swap_range)+j][5] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_25pct_kp2 = [results[i*len(prob_swap_range)+j][6] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_50pct_kp2 = [results[i*len(prob_swap_range)+j][7] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_75pct_kp2 = [results[i*len(prob_swap_range)+j][8] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_90pct_kp2 = [results[i*len(prob_swap_range)+j][9] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_10pct_kp2 = [results[i*len(prob_swap_range)+j][12] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_25pct_kp2 = [results[i*len(prob_swap_range)+j][13] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_50pct_kp2 = [results[i*len(prob_swap_range)+j][14] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_75pct_kp2 = [results[i*len(prob_swap_range)+j][15] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_90pct_kp2 = [results[i*len(prob_swap_range)+j][16] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]

virtual_node_degree_10pct_kp2 = np.reshape(virtual_node_degree_10pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_25pct_kp2 = np.reshape(virtual_node_degree_25pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_50pct_kp2 = np.reshape(virtual_node_degree_50pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_75pct_kp2 = np.reshape(virtual_node_degree_75pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_90pct_kp2 = np.reshape(virtual_node_degree_90pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_10pct_kp2 = np.reshape(virtual_neighbourhood_size_10pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_25pct_kp2 = np.reshape(virtual_neighbourhood_size_25pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_50pct_kp2 = np.reshape(virtual_neighbourhood_size_50pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_75pct_kp2 = np.reshape(virtual_neighbourhood_size_75pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_90pct_kp2 = np.reshape(virtual_neighbourhood_size_90pct_kp2, (len(max_link_dist_range), len(prob_swap_range)))


results = np.load('FOLDER_LOCATION/Infinite networks/Infinite honeycomb/sweep_prob_swap_max_link_dist/results.npy')

virtual_node_degree_mean_kp3 = [results[i*len(prob_swap_range)+j][0] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_mean_kp3 = [results[i*len(prob_swap_range)+j][2] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]

virtual_node_degree_mean_kp3 = np.reshape(virtual_node_degree_mean_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_mean_kp3 = np.reshape(virtual_neighbourhood_size_mean_kp3, (len(max_link_dist_range), len(prob_swap_range)))

virtual_node_degree_10pct_kp3 = [results[i*len(prob_swap_range)+j][5] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_25pct_kp3 = [results[i*len(prob_swap_range)+j][6] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_50pct_kp3 = [results[i*len(prob_swap_range)+j][7] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_75pct_kp3 = [results[i*len(prob_swap_range)+j][8] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_90pct_kp3 = [results[i*len(prob_swap_range)+j][9] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_10pct_kp3 = [results[i*len(prob_swap_range)+j][12] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_25pct_kp3 = [results[i*len(prob_swap_range)+j][13] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_50pct_kp3 = [results[i*len(prob_swap_range)+j][14] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_75pct_kp3 = [results[i*len(prob_swap_range)+j][15] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_90pct_kp3 = [results[i*len(prob_swap_range)+j][16] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]

virtual_node_degree_10pct_kp3 = np.reshape(virtual_node_degree_10pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_25pct_kp3 = np.reshape(virtual_node_degree_25pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_50pct_kp3 = np.reshape(virtual_node_degree_50pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_75pct_kp3 = np.reshape(virtual_node_degree_75pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_90pct_kp3 = np.reshape(virtual_node_degree_90pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_10pct_kp3 = np.reshape(virtual_neighbourhood_size_10pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_25pct_kp3 = np.reshape(virtual_neighbourhood_size_25pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_50pct_kp3 = np.reshape(virtual_neighbourhood_size_50pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_75pct_kp3 = np.reshape(virtual_neighbourhood_size_75pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_90pct_kp3 = np.reshape(virtual_neighbourhood_size_90pct_kp3, (len(max_link_dist_range), len(prob_swap_range)))


results = np.load('FOLDER_LOCATION/Infinite networks/Infinite square/sweep_prob_swap_max_link_dist/results.npy')

virtual_node_degree_mean_kp4 = [results[i*len(prob_swap_range)+j][0] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_mean_kp4 = [results[i*len(prob_swap_range)+j][2] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]

virtual_node_degree_mean_kp4 = np.reshape(virtual_node_degree_mean_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_mean_kp4 = np.reshape(virtual_neighbourhood_size_mean_kp4, (len(max_link_dist_range), len(prob_swap_range)))

virtual_node_degree_10pct_kp4 = [results[i*len(prob_swap_range)+j][5] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_25pct_kp4 = [results[i*len(prob_swap_range)+j][6] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_50pct_kp4 = [results[i*len(prob_swap_range)+j][7] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_75pct_kp4 = [results[i*len(prob_swap_range)+j][8] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_90pct_kp4 = [results[i*len(prob_swap_range)+j][9] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_10pct_kp4 = [results[i*len(prob_swap_range)+j][12] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_25pct_kp4 = [results[i*len(prob_swap_range)+j][13] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_50pct_kp4 = [results[i*len(prob_swap_range)+j][14] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_75pct_kp4 = [results[i*len(prob_swap_range)+j][15] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_90pct_kp4 = [results[i*len(prob_swap_range)+j][16] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]

virtual_node_degree_10pct_kp4 = np.reshape(virtual_node_degree_10pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_25pct_kp4 = np.reshape(virtual_node_degree_25pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_50pct_kp4 = np.reshape(virtual_node_degree_50pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_75pct_kp4 = np.reshape(virtual_node_degree_75pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_90pct_kp4 = np.reshape(virtual_node_degree_90pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_10pct_kp4 = np.reshape(virtual_neighbourhood_size_10pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_25pct_kp4 = np.reshape(virtual_neighbourhood_size_25pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_50pct_kp4 = np.reshape(virtual_neighbourhood_size_50pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_75pct_kp4 = np.reshape(virtual_neighbourhood_size_75pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_90pct_kp4 = np.reshape(virtual_neighbourhood_size_90pct_kp4, (len(max_link_dist_range), len(prob_swap_range)))


results = np.load('FOLDER_LOCATION/Infinite networks/Infinite triangular/sweep_prob_swap_max_link_dist/results.npy')

virtual_node_degree_mean_kp6 = [results[i*len(prob_swap_range)+j][0] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_mean_kp6 = [results[i*len(prob_swap_range)+j][2] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]

virtual_node_degree_mean_kp6 = np.reshape(virtual_node_degree_mean_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_mean_kp6 = np.reshape(virtual_neighbourhood_size_mean_kp6, (len(max_link_dist_range), len(prob_swap_range)))

virtual_node_degree_10pct_kp6 = [results[i*len(prob_swap_range)+j][5] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_25pct_kp6 = [results[i*len(prob_swap_range)+j][6] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_50pct_kp6 = [results[i*len(prob_swap_range)+j][7] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_75pct_kp6 = [results[i*len(prob_swap_range)+j][8] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_node_degree_90pct_kp6 = [results[i*len(prob_swap_range)+j][9] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_10pct_kp6 = [results[i*len(prob_swap_range)+j][12] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_25pct_kp6 = [results[i*len(prob_swap_range)+j][13] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_50pct_kp6 = [results[i*len(prob_swap_range)+j][14] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_75pct_kp6 = [results[i*len(prob_swap_range)+j][15] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]
virtual_neighbourhood_size_90pct_kp6 = [results[i*len(prob_swap_range)+j][16] for i in range(len(max_link_dist_range)) for j in range(len(prob_swap_range))]

virtual_node_degree_10pct_kp6 = np.reshape(virtual_node_degree_10pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_25pct_kp6 = np.reshape(virtual_node_degree_25pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_50pct_kp6 = np.reshape(virtual_node_degree_50pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_75pct_kp6 = np.reshape(virtual_node_degree_75pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_node_degree_90pct_kp6 = np.reshape(virtual_node_degree_90pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_10pct_kp6 = np.reshape(virtual_neighbourhood_size_10pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_25pct_kp6 = np.reshape(virtual_neighbourhood_size_25pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_50pct_kp6 = np.reshape(virtual_neighbourhood_size_50pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_75pct_kp6 = np.reshape(virtual_neighbourhood_size_75pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))
virtual_neighbourhood_size_90pct_kp6 = np.reshape(virtual_neighbourhood_size_90pct_kp6, (len(max_link_dist_range), len(prob_swap_range)))

# %%
def adjust_lightness(color, amount=0.5):
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], max(0, min(1, amount * c[1])), c[2])

# %% [markdown]
# ### Thesis plot

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

plt.style.use('FOLDER_LOCATION/figure.mplstyle')

mm = 1/25.4
outward = 4
color_virtual_node_degree = '#0066A2'
color_virtual_neighbourhood_size = '#EB7246'
color_text = (0, 0, 0, 0.8)
ligthness_control_k = 0.36
lightness_control_V = 0.12

fig, ax = plt.subplots(2, 4, constrained_layout=True, figsize=[(157.5+23)*mm, 157.5*mm/16*8], sharex='col', sharey='row')

y_max_k = 42
y_max_v = 12
ratio = 1.25

for i in range(0, len(max_link_dist_range)):
    ax[0, 0].plot(prob_swap_range, virtual_node_degree_mean_kp2[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
    ax[1, 0].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
    if i < len(max_link_dist_range) - 1:
        ax[1, 0].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

ax[0, 0].set_aspect(1/(y_max_k*ratio))
ax[0, 0].set_ylim([0-0.04*y_max_k, y_max_k+0.01*y_max_k])

ax[0, 0].spines['left'].set_position(('outward', outward))
ax[0, 0].spines['left'].set_bounds(0, y_max_k)
ax[0, 0].set_yticks(ticks=[0, y_max_k])
ax[0, 0].set_yticks(ticks=[14, 28], minor=True)
ax[0, 0].set_yticklabels(labels=[14, 28], minor=True, ha='right')

ax[0, 0].spines['bottom'].set_position(('outward', outward))
ax[0, 0].spines['bottom'].set_bounds(0, 1)

ax[1, 0].set_aspect(1/(y_max_v*ratio))
ax[1, 0].set_ylim([0-0.04*y_max_v, y_max_v+0.01*y_max_v])

ax[1, 0].spines['left'].set_position(('outward', outward))
ax[1, 0].spines['left'].set_bounds(0, y_max_v)
ax[1, 0].set_yticks(ticks=[0, y_max_v])
ax[1, 0].set_yticks(ticks=[4, 8], minor=True)
ax[1, 0].set_yticklabels(labels=[4, 8], minor=True, ha='right')

ax[1, 0].spines['bottom'].set_position(('outward', outward))
ax[1, 0].spines['bottom'].set_bounds(0, 1)
ax[1, 0].set_xticks(ticks=[0, 1], minor=False)
ax[1, 0].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 0].set_title(r'$k_{\mathrm{p}}=2$', color=color_text, y=1, loc='center')  
    
ax[0, 0].set_ylabel(r'$\langle k_i(t)\rangle$', rotation=0, y=0.92, labelpad = 19.5, ha='right')
ax[1, 0].set_ylabel(r'$\langle v_i(t) \rangle$', rotation=0, y=0.92, labelpad = 19.5, ha='right')


for i in range(0, len(max_link_dist_range)):
    ax[0, 1].plot(prob_swap_range, virtual_node_degree_mean_kp3[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
    ax[1, 1].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
    if i < len(max_link_dist_range) - 1:
        ax[1, 1].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

ax[0, 1].spines['left'].set_position(('outward', outward))
ax[0, 1].spines['left'].set_bounds(0, y_max_k)
ax[0, 1].spines['bottom'].set_position(('outward', outward))
ax[0, 1].spines['bottom'].set_bounds(0, 1)

ax[1, 1].spines['left'].set_position(('outward', outward))
ax[1, 1].spines['left'].set_bounds(0, y_max_v)
ax[1, 1].spines['bottom'].set_position(('outward', outward))
ax[1, 1].spines['bottom'].set_bounds(0, 1)
ax[1, 1].set_xticks(ticks=[0, 1], minor=False)
ax[1, 1].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 1].set_title(r'$k_{\mathrm{p}}=3$', color=color_text, y=1, loc='center')


for i in range(0, len(max_link_dist_range)):
    ax[0, 2].plot(prob_swap_range, virtual_node_degree_mean_kp4[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
    ax[1, 2].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
    if i < len(max_link_dist_range) - 1:
        ax[1, 2].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

ax[0, 2].spines['left'].set_position(('outward', outward))
ax[0, 2].spines['left'].set_bounds(0, y_max_k)
ax[0, 2].spines['bottom'].set_position(('outward', outward))
ax[0, 2].spines['bottom'].set_bounds(0, 1)

ax[1, 2].spines['left'].set_position(('outward', outward))
ax[1, 2].spines['left'].set_bounds(0, y_max_v)
ax[1, 2].spines['bottom'].set_position(('outward', outward))
ax[1, 2].spines['bottom'].set_bounds(0, 1)
ax[1, 2].set_xticks(ticks=[0, 1], minor=False)
ax[1, 2].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 2].set_title(r'$k_{\mathrm{p}}=4$', color=color_text, y=1, loc='center')  


for i in range(0, len(max_link_dist_range)):
    ax[0, 3].plot(prob_swap_range, virtual_node_degree_mean_kp6[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
    ax[1, 3].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
    if i < len(max_link_dist_range) - 1:
        ax[1, 3].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

ax[0, 3].spines['left'].set_position(('outward', outward))
ax[0, 3].spines['left'].set_bounds(0, y_max_k)
ax[0, 3].spines['bottom'].set_position(('outward', outward))
ax[0, 3].spines['bottom'].set_bounds(0, 1)

ax[1, 3].spines['left'].set_position(('outward', outward))
ax[1, 3].spines['left'].set_bounds(0, y_max_v)
ax[1, 3].spines['bottom'].set_position(('outward', outward))
ax[1, 3].spines['bottom'].set_bounds(0, 1)
ax[1, 3].set_xticks(ticks=[0, 1], minor=False)
ax[1, 3].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 3].set_title(r'$k_{\mathrm{p}}=6$', color=color_text, y=1, loc='center')  

fig.supxlabel(r'Swap probability $q$', x=0.55, color=color_text, fontsize=10)

fig.set_facecolor('white')

axins = ax[1, 3].inset_axes([0.52, 0.45, 0.25, 0.25*2.2])
for i in range(0, len(max_link_dist_range)):
    axins.plot(prob_swap_range, virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
    axins.plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

    # sub region of the original image
axins.set_xlim(0.08, 0.18)
axins.set_ylim(8, 10.2)
axins.set_xticklabels([])
axins.set_yticklabels([])
axins.set_xticks([])
axins.set_yticks([])
axins.spines['top'].set_visible(True)
axins.spines['right'].set_visible(True)
axins.spines['right'].set_color('darkgray')
axins.spines['bottom'].set_color('darkgray')
axins.spines['left'].set_color('darkgray')
axins.spines['top'].set_color('darkgray')

rectpatch, connects = ax[1, 3].indicate_inset_zoom(axins, edgecolor='darkgray', alpha=1, linewidth=0.8)
connects[0].set_linewidth(0.8)
connects[1].set_linewidth(0.8)


ax[1, 3].text(0.82, 11.1, r'$0.96$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0))
ax[1, 3].text(0.82, 9.9, r'$0.90$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*1))
ax[1, 3].text(0.82, 8, r'$0.81$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2))
ax[1, 3].text(0.82, 5, r'$0.72$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*3))
ax[1, 3].text(-0.03, 1.75, r'$F_{\mathrm{gen}}=$', fontsize=9, color=color_text)
ax[1, 3].text(0.25, 1.75, r'$0.52$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4))

# fig.savefig('FOLDER_LOCATION/infinite networks/sweep_prob_swap_max_swap_dist.pdf', bbox_inches = 'tight', pad_inches=0*mm)
# Out:
# Text(0.25, 1.75, '$0.52$')

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

plt.style.use('C:/Users/larst/Dropbox/MTP_Lars_Talsma/GitHub/CD-regular-networks/CD-regular-networks/figure.mplstyle')

mm = 1/25.4
outward = 4
color_virtual_node_degree = '#0066A2'
color_virtual_neighbourhood_size = '#EB7246'
color_text = (0, 0, 0, 0.8)
ligthness_control_k = 0.36
lightness_control_V = 0.12

fig, ax = plt.subplots(2, 4, constrained_layout=True, figsize=[(157.5+23)*mm, 157.5*mm/16*8], sharex='col', sharey='row')

y_max_k = 42
y_max_v = 12
ratio = 1.25

# for i in [1, 3, 4]:
#     ax[0, 0].plot(prob_swap_range, virtual_node_degree_mean_kp2[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
#     ax[1, 0].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
#     if i < len(max_link_dist_range) - 1:
#         ax[1, 0].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

ax[0, 0].plot(prob_swap_range, virtual_node_degree_mean_kp2[len(max_link_dist_range)-2, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*0), label=max_link_dist_range[len(max_link_dist_range)-2], zorder=10)
ax[0, 0].plot(prob_swap_range, virtual_node_degree_mean_kp2[len(max_link_dist_range)-4, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*2), label=max_link_dist_range[len(max_link_dist_range)-4], zorder=9)
ax[0, 0].plot(prob_swap_range, virtual_node_degree_mean_kp2[len(max_link_dist_range)-5, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*4), label=max_link_dist_range[len(max_link_dist_range)-5], zorder=8)


ax[1, 0].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-2, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), label=max_link_dist_range[len(max_link_dist_range)-2], zorder=10)
ax[1, 0].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-4, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), label=max_link_dist_range[len(max_link_dist_range)-4], zorder=9)
ax[1, 0].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-5, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), label=max_link_dist_range[len(max_link_dist_range)-5], zorder=8)

ax[1, 0].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-2, :])], np.max(virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-2, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), markersize=6, markeredgewidth=0)
ax[1, 0].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-4, :])], np.max(virtual_neighbourhood_size_mean_kp2[len(max_link_dist_range)-4, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), markersize=6, markeredgewidth=0)


ax[0, 0].set_aspect(1/(y_max_k*ratio))
ax[0, 0].set_ylim([0-0.04*y_max_k, y_max_k+0.01*y_max_k])

ax[0, 0].spines['left'].set_position(('outward', outward))
ax[0, 0].spines['left'].set_bounds(0, y_max_k)
ax[0, 0].set_yticks(ticks=[0, y_max_k])
ax[0, 0].set_yticks(ticks=[14, 28], minor=True)
ax[0, 0].set_yticklabels(labels=[14, 28], minor=True, ha='right')

ax[0, 0].spines['bottom'].set_position(('outward', outward))
ax[0, 0].spines['bottom'].set_bounds(0, 1)

ax[1, 0].set_aspect(1/(y_max_v*ratio))
ax[1, 0].set_ylim([0-0.04*y_max_v, y_max_v+0.01*y_max_v])

ax[1, 0].spines['left'].set_position(('outward', outward))
ax[1, 0].spines['left'].set_bounds(0, y_max_v)
ax[1, 0].set_yticks(ticks=[0, y_max_v])
ax[1, 0].set_yticks(ticks=[4, 8], minor=True)
ax[1, 0].set_yticklabels(labels=[4, 8], minor=True, ha='right')

ax[1, 0].spines['bottom'].set_position(('outward', outward))
ax[1, 0].spines['bottom'].set_bounds(0, 1)
ax[1, 0].set_xticks(ticks=[0, 1], minor=False)
ax[1, 0].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 0].set_title(r'$k_{\mathrm{p}}=2$', color=color_text, y=1, loc='center')  
    
ax[0, 0].set_ylabel(r'$\langle k_i(t)\rangle$', rotation=0, y=0.92, labelpad = 19.5, ha='right')
ax[1, 0].set_ylabel(r'$\langle v_i(t) \rangle$', rotation=0, y=0.92, labelpad = 19.5, ha='right')


# for i in [1, 3, 4]:
#     ax[0, 1].plot(prob_swap_range, virtual_node_degree_mean_kp3[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
#     ax[1, 1].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
#     if i < len(max_link_dist_range) - 1:
#         ax[1, 1].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

ax[0, 1].plot(prob_swap_range, virtual_node_degree_mean_kp3[len(max_link_dist_range)-2, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*0), label=max_link_dist_range[len(max_link_dist_range)-2], zorder=10)
ax[0, 1].plot(prob_swap_range, virtual_node_degree_mean_kp3[len(max_link_dist_range)-4, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*2), label=max_link_dist_range[len(max_link_dist_range)-4], zorder=9)
ax[0, 1].plot(prob_swap_range, virtual_node_degree_mean_kp3[len(max_link_dist_range)-5, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*4), label=max_link_dist_range[len(max_link_dist_range)-5], zorder=8)


ax[1, 1].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-2, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), label=max_link_dist_range[len(max_link_dist_range)-2], zorder=10)
ax[1, 1].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-4, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), label=max_link_dist_range[len(max_link_dist_range)-4], zorder=9)
ax[1, 1].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-5, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), label=max_link_dist_range[len(max_link_dist_range)-5], zorder=8)

ax[1, 1].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-2, :])], np.max(virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-2, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), markersize=6, markeredgewidth=0)
ax[1, 1].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-4, :])], np.max(virtual_neighbourhood_size_mean_kp3[len(max_link_dist_range)-4, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), markersize=6, markeredgewidth=0)


ax[0, 1].spines['left'].set_position(('outward', outward))
ax[0, 1].spines['left'].set_bounds(0, y_max_k)
ax[0, 1].spines['bottom'].set_position(('outward', outward))
ax[0, 1].spines['bottom'].set_bounds(0, 1)

ax[1, 1].spines['left'].set_position(('outward', outward))
ax[1, 1].spines['left'].set_bounds(0, y_max_v)
ax[1, 1].spines['bottom'].set_position(('outward', outward))
ax[1, 1].spines['bottom'].set_bounds(0, 1)
ax[1, 1].set_xticks(ticks=[0, 1], minor=False)
ax[1, 1].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 1].set_title(r'$k_{\mathrm{p}}=3$', color=color_text, y=1, loc='center')


# for i in [1, 3, 4]:
#     ax[0, 2].plot(prob_swap_range, virtual_node_degree_mean_kp4[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
#     ax[1, 2].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
#     if i < len(max_link_dist_range) - 1:
#         ax[1, 2].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

ax[0, 2].plot(prob_swap_range, virtual_node_degree_mean_kp4[len(max_link_dist_range)-2, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*0), label=max_link_dist_range[len(max_link_dist_range)-2], zorder=10)
ax[0, 2].plot(prob_swap_range, virtual_node_degree_mean_kp4[len(max_link_dist_range)-4, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*2), label=max_link_dist_range[len(max_link_dist_range)-4], zorder=9)
ax[0, 2].plot(prob_swap_range, virtual_node_degree_mean_kp4[len(max_link_dist_range)-5, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*4), label=max_link_dist_range[len(max_link_dist_range)-5], zorder=8)


ax[1, 2].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-2, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), label=max_link_dist_range[len(max_link_dist_range)-2], zorder=10)
ax[1, 2].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-4, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), label=max_link_dist_range[len(max_link_dist_range)-4], zorder=9)
ax[1, 2].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-5, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), label=max_link_dist_range[len(max_link_dist_range)-5], zorder=8)

ax[1, 2].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-2, :])], np.max(virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-2, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), markersize=6, markeredgewidth=0)
ax[1, 2].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-4, :])], np.max(virtual_neighbourhood_size_mean_kp4[len(max_link_dist_range)-4, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), markersize=6, markeredgewidth=0)
        
        
ax[0, 2].spines['left'].set_position(('outward', outward))
ax[0, 2].spines['left'].set_bounds(0, y_max_k)
ax[0, 2].spines['bottom'].set_position(('outward', outward))
ax[0, 2].spines['bottom'].set_bounds(0, 1)

ax[1, 2].spines['left'].set_position(('outward', outward))
ax[1, 2].spines['left'].set_bounds(0, y_max_v)
ax[1, 2].spines['bottom'].set_position(('outward', outward))
ax[1, 2].spines['bottom'].set_bounds(0, 1)
ax[1, 2].set_xticks(ticks=[0, 1], minor=False)
ax[1, 2].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 2].set_title(r'$k_{\mathrm{p}}=4$', color=color_text, y=1, loc='center')  


# for i in [1, 3, 4]:
#     ax[0, 3].plot(prob_swap_range, virtual_node_degree_mean_kp6[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
#     ax[1, 3].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
#     if i < len(max_link_dist_range) - 1:
#         ax[1, 3].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

ax[0, 3].plot(prob_swap_range, virtual_node_degree_mean_kp6[len(max_link_dist_range)-2, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*0), label=max_link_dist_range[len(max_link_dist_range)-2], zorder=10)
ax[0, 3].plot(prob_swap_range, virtual_node_degree_mean_kp6[len(max_link_dist_range)-4, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*2), label=max_link_dist_range[len(max_link_dist_range)-4], zorder=9)
ax[0, 3].plot(prob_swap_range, virtual_node_degree_mean_kp6[len(max_link_dist_range)-5, :], '-', color=adjust_lightness(color_virtual_node_degree, 1+ligthness_control_k*4), label=max_link_dist_range[len(max_link_dist_range)-5], zorder=8)


ax[1, 3].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-2, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), label=max_link_dist_range[len(max_link_dist_range)-2], zorder=10)
ax[1, 3].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-4, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), label=max_link_dist_range[len(max_link_dist_range)-4], zorder=9)
ax[1, 3].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-5, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4), label=max_link_dist_range[len(max_link_dist_range)-5], zorder=8)

ax[1, 3].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-2, :])], np.max(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-2, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0), markersize=6, markeredgewidth=0)
ax[1, 3].plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-4, :])], np.max(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-4, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2), markersize=6, markeredgewidth=0)



ax[0, 3].spines['left'].set_position(('outward', outward))
ax[0, 3].spines['left'].set_bounds(0, y_max_k)
ax[0, 3].spines['bottom'].set_position(('outward', outward))
ax[0, 3].spines['bottom'].set_bounds(0, 1)

ax[1, 3].spines['left'].set_position(('outward', outward))
ax[1, 3].spines['left'].set_bounds(0, y_max_v)
ax[1, 3].spines['bottom'].set_position(('outward', outward))
ax[1, 3].spines['bottom'].set_bounds(0, 1)
ax[1, 3].set_xticks(ticks=[0, 1], minor=False)
ax[1, 3].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

ax[0, 3].set_title(r'$k_{\mathrm{p}}=6$', color=color_text, y=1, loc='center')  

fig.supxlabel(r'Swap probability $q$', x=0.55, color=color_text, fontsize=10)

fig.set_facecolor('white')

# axins = ax[1, 3].inset_axes([0.52, 0.45, 0.25, 0.25*2.2])
# for i in range(0, len(max_link_dist_range)):
#     axins.plot(prob_swap_range, virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :], '-', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), label=max_link_dist_range[len(max_link_dist_range)-i-1], zorder=10-i)
#     axins.plot(prob_swap_range[np.argmax(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :])], np.max(virtual_neighbourhood_size_mean_kp6[len(max_link_dist_range)-i-1, :]), '.', color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*i), markersize=6, markeredgewidth=0)

#     # sub region of the original image
# axins.set_xlim(0.08, 0.18)
# axins.set_ylim(8, 10.2)
# axins.set_xticklabels([])
# axins.set_yticklabels([])
# axins.set_xticks([])
# axins.set_yticks([])
# axins.spines['top'].set_visible(True)
# axins.spines['right'].set_visible(True)
# axins.spines['right'].set_color('darkgray')
# axins.spines['bottom'].set_color('darkgray')
# axins.spines['left'].set_color('darkgray')
# axins.spines['top'].set_color('darkgray')

# rectpatch, connects = ax[1, 3].indicate_inset_zoom(axins, edgecolor='darkgray', alpha=1, linewidth=0.8)
# connects[0].set_linewidth(0.8)
# connects[1].set_linewidth(0.8)


# ax[1, 3].text(0.82, 11.1, r'$0.96$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*0))
ax[1, 3].text(0.02, 10.5, r'$0.90$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*1))
# ax[1, 3].text(0.82, 8, r'$0.81$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*2))
ax[1, 3].text(0.038, 6.4, r'$0.72$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*3))
ax[1, 3].text(-0.03, 1.75, r'$F_{\mathrm{gen}}=$', fontsize=9, color=color_text)
ax[1, 3].text(0.25, 1.75, r'$0.52$', fontsize=9, color=adjust_lightness(color_virtual_neighbourhood_size, 0.9+lightness_control_V*4))

# fig.savefig('FOLDER_LOCATION/infinite networks/sweep_prob_swap_max_swap_dist.pdf', bbox_inches = 'tight', pad_inches=0*mm)
# Out:
# Text(0.25, 1.75, '$0.52$')

# %% [markdown]
# ### Distribution plot

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
plt.style.use('FOLDER_LOCATION/figure.mplstyle')

mm = 1/25.4
outward = 4
color_virtual_node_degree = '#0066A2'
color_virtual_neighbourhood_size = '#EB7246'
color_text = (0, 0, 0, 0.8)

fig, ax = plt.subplots(8, 5, constrained_layout=True, figsize=[(157.5+23)*mm, 157.5*mm*np.sqrt(2)], sharex='col', sharey='row')

for i in range(0, len(max_link_dist_range)):
    y_max_k = virtual_node_degree_90pct_kp2.max()
    y_max_v = 6
    ratio = 1.25
    
    ax[0, i].set_aspect(1/(y_max_k*ratio), share=False)
    ax[0, i].set_ylim([0-0.04*y_max_k, y_max_k+0.01*y_max_k])

    ax[1, i].set_aspect(1/(y_max_v*ratio), share=False)
    ax[1, i].set_ylim([0-0.04*y_max_v, y_max_v+0.01*y_max_v])
    
    ax[0, i].plot(prob_swap_range, virtual_node_degree_mean_kp2[i, :], '-', color=color_virtual_node_degree)
    ax[0, i].fill_between(prob_swap_range, virtual_node_degree_25pct_kp2[i, :], virtual_node_degree_75pct_kp2[i, :], facecolor=color_virtual_node_degree, alpha=0.5, label=r'25--75th percentile')
    ax[0, i].fill_between(prob_swap_range, virtual_node_degree_10pct_kp2[i, :], virtual_node_degree_25pct_kp2[i, :], facecolor=color_virtual_node_degree, alpha=0.2, label=r'10--90th percentile')
    ax[0, i].fill_between(prob_swap_range, virtual_node_degree_75pct_kp2[i, :], virtual_node_degree_90pct_kp2[i, :], facecolor=color_virtual_node_degree, alpha=0.2)

    ax[0, i].spines['left'].set_position(('outward', outward))
    ax[0, i].spines['left'].set_bounds(0, y_max_k)
    ax[0, i].set_yticks(ticks=[0, y_max_k])
    ax[0, i].set_yticks(ticks=[7], minor=True)
    ax[0, i].set_yticklabels([7], minor=True)

    ax[0, i].spines['bottom'].set_position(('outward', outward))
    ax[0, i].spines['bottom'].set_bounds(0, 1)
        
    ax[1, i].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp2[i, :], '-', color=color_virtual_neighbourhood_size)
    ax[1, i].fill_between(prob_swap_range, virtual_neighbourhood_size_25pct_kp2[i, :], virtual_neighbourhood_size_75pct_kp2[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.5, label=r'25--75th percentile')
    ax[1, i].fill_between(prob_swap_range, virtual_neighbourhood_size_10pct_kp2[i, :], virtual_neighbourhood_size_25pct_kp2[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.2, label=r'10--90th percentile')
    ax[1, i].fill_between(prob_swap_range, virtual_neighbourhood_size_75pct_kp2[i, :], virtual_neighbourhood_size_90pct_kp2[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.2)

    ax[1, i].spines['left'].set_position(('outward', outward))
    ax[1, i].spines['left'].set_bounds(0, y_max_v)
    ax[1, i].set_yticks(ticks=[0, y_max_v])
    ax[1, i].set_yticks(ticks=[2, 4], minor=True)
    ax[1, i].set_yticklabels([2, 4], minor=True)


    ax[1, i].spines['bottom'].set_position(('outward', outward))
    ax[1, i].spines['bottom'].set_bounds(0, 1)
    ax[1, i].set_xticks(ticks=[0, 1], minor=False)
    ax[1, i].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)
    

ax[0, 0].set_title(r'$F_{\mathrm{gen}}=0.52$', color=color_text, fontsize=10, y=1.2, loc='center')    
ax[0, 1].set_title(r'$F_{\mathrm{gen}}=0.72$', color=color_text, fontsize=10, y=1.2, loc='center')    
ax[0, 2].set_title(r'$F_{\mathrm{gen}}=0.81$', color=color_text, fontsize=10, y=1.2, loc='center')    
ax[0, 3].set_title(r'$F_{\mathrm{gen}}=0.90$', color=color_text, fontsize=10, y=1.2, loc='center')    
ax[0, 4].set_title(r'$F_{\mathrm{gen}}=0.96$', color=color_text, fontsize=10, y=1.2, loc='center')    


for i in range(0, len(max_link_dist_range)):
    y_max_k = virtual_node_degree_90pct_kp3.max()
    y_max_v = 9
    ratio = 1.25
    
    ax[2, i].set_aspect(1/(y_max_k*ratio), share=False)
    ax[2, i].set_ylim([0-0.04*y_max_k, y_max_k+0.01*y_max_k])

    ax[3, i].set_aspect(1/(y_max_v*ratio), share=False)
    ax[3, i].set_ylim([0-0.04*y_max_v, y_max_v+0.01*y_max_v])
    
    ax[2, i].plot(prob_swap_range, virtual_node_degree_mean_kp3[i, :], '-', color=color_virtual_node_degree)
    ax[2, i].fill_between(prob_swap_range, virtual_node_degree_25pct_kp3[i, :], virtual_node_degree_75pct_kp3[i, :], facecolor=color_virtual_node_degree, alpha=0.5)
    ax[2, i].fill_between(prob_swap_range, virtual_node_degree_10pct_kp3[i, :], virtual_node_degree_25pct_kp3[i, :], facecolor=color_virtual_node_degree, alpha=0.2)
    ax[2, i].fill_between(prob_swap_range, virtual_node_degree_75pct_kp3[i, :], virtual_node_degree_90pct_kp3[i, :], facecolor=color_virtual_node_degree, alpha=0.2)

    ax[2, i].spines['left'].set_position(('outward', outward))
    ax[2, i].spines['left'].set_bounds(0, virtual_node_degree_90pct_kp3.max())
    ax[2, i].set_yticks(ticks=[0, virtual_node_degree_90pct_kp3.max()])
    ax[2, i].set_yticks(ticks=[7, 14], minor=True)
    ax[2, i].set_yticklabels([7, 14], minor=True)
    
    ax[2, i].spines['bottom'].set_position(('outward', outward))
    ax[2, i].spines['bottom'].set_bounds(0, 1)
    ax[2, i].set_xticklabels([])
        
    ax[3, i].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp3[i, :], '-', color=color_virtual_neighbourhood_size)
    ax[3, i].fill_between(prob_swap_range, virtual_neighbourhood_size_25pct_kp3[i, :], virtual_neighbourhood_size_75pct_kp3[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.5)
    ax[3, i].fill_between(prob_swap_range, virtual_neighbourhood_size_10pct_kp3[i, :], virtual_neighbourhood_size_25pct_kp3[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.2)
    ax[3, i].fill_between(prob_swap_range, virtual_neighbourhood_size_75pct_kp3[i, :], virtual_neighbourhood_size_90pct_kp3[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.2)

    ax[3, i].spines['left'].set_position(('outward', outward))
    ax[3, i].spines['left'].set_bounds(0, y_max_v)
    ax[3, i].set_yticks(ticks=[0, y_max_v])
    ax[3, i].set_yticks(ticks=[3, 6], minor=True)
    ax[3, i].set_yticklabels([3, 6], minor=True)

    ax[3, i].spines['bottom'].set_position(('outward', outward))
    ax[3, i].spines['bottom'].set_bounds(0, 1)
    ax[3, i].set_xticks(ticks=[0, 1], minor=False)
    ax[3, i].set_xticklabels(labels=[0, 1], minor=False)
    ax[1, i].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)

for i in range(0, len(max_link_dist_range)):
    y_max_k = virtual_node_degree_90pct_kp4.max()
    y_max_v = 12
    ratio = 1.25
    
    ax[4, i].set_aspect(1/(y_max_k*ratio), share=False)
    ax[4, i].set_ylim([0-0.04*y_max_k, y_max_k+0.01*y_max_k])

    ax[5, i].set_aspect(1/(y_max_v*ratio), share=False)
    ax[5, i].set_ylim([0-0.04*y_max_v, y_max_v+0.01*y_max_v])
    
    ax[4, i].plot(prob_swap_range, virtual_node_degree_mean_kp4[i, :], '-', color=color_virtual_node_degree)
    ax[4, i].fill_between(prob_swap_range, virtual_node_degree_25pct_kp4[i, :], virtual_node_degree_75pct_kp4[i, :], facecolor=color_virtual_node_degree, alpha=0.5)
    ax[4, i].fill_between(prob_swap_range, virtual_node_degree_10pct_kp4[i, :], virtual_node_degree_25pct_kp4[i, :], facecolor=color_virtual_node_degree, alpha=0.2)
    ax[4, i].fill_between(prob_swap_range, virtual_node_degree_75pct_kp4[i, :], virtual_node_degree_90pct_kp4[i, :], facecolor=color_virtual_node_degree, alpha=0.2)

    ax[4, i].spines['left'].set_position(('outward', outward))
    ax[4, i].spines['left'].set_bounds(0, virtual_node_degree_90pct_kp4.max())
    ax[4, i].set_yticks(ticks=[0, virtual_node_degree_90pct_kp4.max()])
    ax[4, i].set_yticks(ticks=[14], minor=True)
    ax[4, i].set_yticklabels([14], minor=True)

    ax[4, i].spines['bottom'].set_position(('outward', outward))
    ax[4, i].spines['bottom'].set_bounds(0, 1)
    ax[4, i].set_xticklabels([])
        
    ax[5, i].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp4[i, :], '-', color=color_virtual_neighbourhood_size)
    ax[5, i].fill_between(prob_swap_range, virtual_neighbourhood_size_25pct_kp4[i, :], virtual_neighbourhood_size_75pct_kp4[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.5)
    ax[5, i].fill_between(prob_swap_range, virtual_neighbourhood_size_10pct_kp4[i, :], virtual_neighbourhood_size_25pct_kp4[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.2)
    ax[5, i].fill_between(prob_swap_range, virtual_neighbourhood_size_75pct_kp4[i, :], virtual_neighbourhood_size_90pct_kp4[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.2)

    ax[5, i].spines['left'].set_position(('outward', outward))
    ax[5, i].spines['left'].set_bounds(0, y_max_v)
    ax[5, i].set_yticks(ticks=[0, y_max_v])
    ax[5, i].set_yticks(ticks=[4, 8], minor=True)
    ax[5, i].set_yticklabels([4, 8], minor=True)

    ax[5, i].spines['bottom'].set_position(('outward', outward))
    ax[5, i].spines['bottom'].set_bounds(0, 1)
    ax[5, i].set_xticks(ticks=[0, 1], minor=False)
    ax[5, i].set_xticklabels(labels=[0, 1], minor=False)
    ax[1, i].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)
    
for i in range(0, len(max_link_dist_range)):
    y_max_k = virtual_node_degree_90pct_kp6.max()
    y_max_v = 12
    ratio = 1.25
    
    ax[6, i].set_aspect(1/(y_max_k*ratio), share=False)
    ax[6, i].set_ylim([0-0.04*y_max_k, y_max_k+0.01*y_max_k])

    ax[7, i].set_aspect(1/(y_max_v*ratio), share=False)
    ax[7, i].set_ylim([0-0.04*y_max_v, y_max_v+0.01*y_max_v])
    
    ax[6, i].plot(prob_swap_range, virtual_node_degree_mean_kp6[i, :], '-', color=color_virtual_node_degree)
    ax[6, i].fill_between(prob_swap_range, virtual_node_degree_25pct_kp6[i, :], virtual_node_degree_75pct_kp6[i, :], facecolor=color_virtual_node_degree, alpha=0.5)
    ax[6, i].fill_between(prob_swap_range, virtual_node_degree_10pct_kp6[i, :], virtual_node_degree_25pct_kp6[i, :], facecolor=color_virtual_node_degree, alpha=0.2)
    ax[6, i].fill_between(prob_swap_range, virtual_node_degree_75pct_kp6[i, :], virtual_node_degree_90pct_kp6[i, :], facecolor=color_virtual_node_degree, alpha=0.2)

    ax[6, i].spines['left'].set_position(('outward', outward))
    ax[6, i].spines['left'].set_bounds(0, virtual_node_degree_90pct_kp6.max())
    ax[6, i].set_yticks(ticks=[0, virtual_node_degree_90pct_kp6.max()])
    ax[6, i].set_yticks(ticks=[14, 28], minor=True)
    ax[6, i].set_yticklabels([14, 28], minor=True)
    
    ax[6, i].spines['bottom'].set_position(('outward', outward))
    ax[6, i].spines['bottom'].set_bounds(0, 1)
    ax[6, i].set_xticklabels([])
        
    ax[7, i].plot(prob_swap_range, virtual_neighbourhood_size_mean_kp6[i, :], '-', color=color_virtual_neighbourhood_size)
    ax[7, i].fill_between(prob_swap_range, virtual_neighbourhood_size_25pct_kp6[i, :], virtual_neighbourhood_size_75pct_kp6[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.5)
    ax[7, i].fill_between(prob_swap_range, virtual_neighbourhood_size_10pct_kp6[i, :], virtual_neighbourhood_size_25pct_kp6[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.2)
    ax[7, i].fill_between(prob_swap_range, virtual_neighbourhood_size_75pct_kp6[i, :], virtual_neighbourhood_size_90pct_kp6[i, :], facecolor=color_virtual_neighbourhood_size, alpha=0.2)

    ax[7, i].spines['left'].set_position(('outward', outward))
    ax[7, i].spines['left'].set_bounds(0, y_max_v)
    ax[7, i].set_yticks(ticks=[0, y_max_v])
    ax[7, i].set_yticks(ticks=[6], minor=True)
    ax[7, i].set_yticklabels([6], minor=True)

    ax[7, i].spines['bottom'].set_position(('outward', outward))
    ax[7, i].spines['bottom'].set_bounds(0, 1)
    ax[7, i].set_xticks(ticks=[0, 1], minor=False)
    ax[7, i].set_xticklabels(labels=[0, 1], minor=False)
    ax[7, i].set_xticks(ticks=[0.25, 0.50, 0.75], minor=True)
    
ax[0, 0].set_ylabel(r'$\langle k_i(t)\rangle$', rotation=0, y=0.89, labelpad = 17.5, ha='right')
ax[1, 0].set_ylabel(r'$\langle v_i(t) \rangle$', rotation=0, y=0.89, labelpad = 23, ha='right')
ax[2, 0].set_ylabel(r'$\langle k_i(t)\rangle$', rotation=0, y=0.89, labelpad = 17.5, ha='right')
ax[3, 0].set_ylabel(r'$\langle v_i(t) \rangle$', rotation=0, y=0.89, labelpad = 23, ha='right')
ax[4, 0].set_ylabel(r'$\langle k_i(t)\rangle$', rotation=0, y=0.89, labelpad = 17.5, ha='right')
ax[5, 0].set_ylabel(r'$\langle v_i(t) \rangle$', rotation=0, y=0.89, labelpad = 17.5, ha='right')
ax[6, 0].set_ylabel(r'$\langle k_i(t)\rangle$', rotation=0, y=0.89, labelpad = 17.5, ha='right')
ax[7, 0].set_ylabel(r'$\langle v_i(t) \rangle$', rotation=0, y=0.89, labelpad = 17.5, ha='right')

ax[0, 2].text(0.5, 14*1.1, r'$k_{\mathrm{p}}=2$', fontsize=10, color=color_text, ha='center')
ax[2, 2].text(0.5, 21*1.1, r'$k_{\mathrm{p}}=3$', fontsize=10, color=color_text, ha='center')
ax[4, 2].text(0.5, 28*1.1, r'$k_{\mathrm{p}}=4$', fontsize=10, color=color_text, ha='center')
ax[6, 2].text(0.5, 42*1.1, r'$k_{\mathrm{p}}=6$', fontsize=10, color=color_text, ha='center')

ax[7, 2].set_xlabel(r'Swap probability $q$', fontsize=10, color=color_text, x=0.5)

ax[1, 4].text(0.48, 4.2, r'25--75\%', ha='left', color=color_virtual_neighbourhood_size, alpha=0.6, fontsize=10)
ax[1, 4].text(0.43, 5.2, r'10--90\%', ha='left', color=color_virtual_neighbourhood_size, alpha=0.3, fontsize=10)
ax[1, 4].plot([0.30, 0.4], [4.6, 5.5], '-', color='gray', linewidth=0.6, zorder=3)
ax[1, 4].plot([0.35, 0.45], [3.6, 4.5], '-', color='gray', linewidth=0.6, zorder=3)

# fig.savefig('FOLDER_LOCATION/sweep_prob_swap_max_swap_dist_distribution.pdf', bbox_inches = 'tight', pad_inches=0*mm)
